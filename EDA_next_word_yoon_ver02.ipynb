# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/song_data_yewon_ver03.csv')

# %%
song = pd.DataFrame(df)

# %%
df2 = pd.read_csv('../Data/idol_list.csv', encoding='euc-kr')

# %%
idol = pd.DataFrame(df2)

# %%
idol.head()
# Out:
#      artist         artist_eng member_num leader_name gender     agency
# 0  서태지와 아이들  SeoTaiji And Boys          3         서태지      남      요요 기획
# 1      더 블루           The Blue          2         손지창      남  SM 엔터테인먼트
# 2         잼                Zam          5         조진수      혼    DSP 미디어
# 3     에스오에스              S.O.S          4         NaN      여    삼포니 레코드
# 4       솔리드              Solid          3         정재윤      남        비앤비

# %%
all = pd.merge(song, idol, on='artist')
all
# Out:
#                       title    artist                                 album  \
# 0                    태지 보이스  서태지와 아이들                            시대유감(時代遺憾)
# 1                시대유감(時代遺憾)  서태지와 아이들                            시대유감(時代遺憾)
# 2                  수시아(誰是我)  서태지와 아이들                            시대유감(時代遺憾)
# 3                Free Style  서태지와 아이들                            시대유감(時代遺憾)
# 4                     난 알아요  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 5              너와 함께한 시간속에서  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 6                   환상속의 그대  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 7                       하여가  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 8                       너에게  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 9                  우리들만의 추억  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 10                  발해를 꿈꾸며  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 11                       영원  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 12                   교실 이데아  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 13           Come Back Home  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 14                    슬픈 아픔  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 15                       필승  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 16                 Good Bye  서태지와 아이들  Seotaji And Boys Good Bye Best Album
# 17                Yo! Taiji  서태지와 아이들                              4집 - 컴백홈
# 18                    슬픈 아픔  서태지와 아이들                              4집 - 컴백홈
# 19                   필승(必勝)  서태지와 아이들                              4집 - 컴백홈
# 20           Come Back Home  서태지와 아이들                              4집 - 컴백홈
# 21               시대유감(詩代遺憾)  서태지와 아이들                              4집 - 컴백홈
# 22     1996, 그들이 지구를 지배했을 때  서태지와 아이들                              4집 - 컴백홈
# 23               Taiji Boys  서태지와 아이들                              4집 - 컴백홈
# 24               Free Style  서태지와 아이들                              4집 - 컴백홈
# 25                   널 지우려해  서태지와 아이들      `95 Taijiboys Concert 다른 하늘이 열리고
# 26                      너에게  서태지와 아이들      `95 Taijiboys Concert 다른 하늘이 열리고
# 27                      수시아  서태지와 아이들      `95 Taijiboys Concert 다른 하늘이 열리고
# 28                       영원  서태지와 아이들      `95 Taijiboys Concert 다른 하늘이 열리고
# 29                    내 맘이야  서태지와 아이들      `95 Taijiboys Concert 다른 하늘이 열리고
# ...                     ...       ...                                   ...
# 12660                 여자사용법     에이오에이                                  사뿐사뿐
# 12661                   단둘이     에이오에이                                  사뿐사뿐
# 12662                  Time     에이오에이                                  사뿐사뿐
# 12663                   휠릴리     에이오에이                                  사뿐사뿐
# 12664               Fantasy     에이오에이                                  단발머리
# 12665     단발머리 (Short Hair)     에이오에이                                  단발머리
# 12666               Joa YO!     에이오에이                                  단발머리
# 12667                  내 반쪽     에이오에이                                  단발머리
# 12668               말이 안 통해     에이오에이                                  단발머리
# 12669       그대, 승리의 날개를 펼쳐라     에이오에이       Red Devil 5th `We Are The Reds`
# 12670     짧은 치마 (Miniskirt)     에이오에이                                 짧은 치마
# 12680  Love is only you<br>Love is only you<br>Love i...
# 12681  너의 달콤했던 속삭임에 속아<br>그저 황홀했던 유혹들에 속아<br>내가 쓰러져 내...
# 12682  Hoo<br>Yeah hey hey hey c'mon<br>La dda dda dd...
# 12683  창밖에 내리는 빗소리<br>흐르는 시간처럼<br>빗물은 흘러내리네<br>내린 빗방울...
# 12684  저 달빛 아래 너와 나<br>손잡고 같이 걸을까 babe<br>나 꿈을 꾸는 것 같...
# 12685  그랬나봐 나 널 좋아하나봐<br>하루하루 니 생각만 나는 걸<br>널 보고 싶다고 ...
# 12686  떨리는 눈빛이 보여<br>알아 니 마음 I Feel ya<br>첨으로 느껴본 감정<...
# 12687  시린 겨울 밤이 지나고<br>흩날리는 꽃잎 사이로<br>지쳐있던 내게로 니가 불어와...
# 12688  일단 올라타 babe<br>이건 꿈같아 되게<br>니가 가고 싶은 곳 편하게 말해줘...
# 12689  난 꿈이 있지<br>오늘도 오늘도 오늘도 Yah<br>내일도 내일도 내일도 Yah<...
#
#                                                 lyricist  \
# 0                                                 서태지
# 1                                                 서태지
# 2                                                 서태지
# 3                                     서태지    ,    김종서
# 4                                                 서태지
# 5                                                 서태지
# 6                                                 서태지
# 7                                                 서태지
# 8                            서태지    ,    WILLIAM BYUN
# 9                                                 서태지
# 10                                                서태지
# 11                                                서태지
# 12                                                서태지
# 13                                                서태지
# 14                                                서태지
# 15                                                서태지
# 16                                                서태지
# 17                                                   NaN
# 18                                                서태지
# 19                                                서태지
# 20                                                서태지
# 21                                                서태지
# 22                                                서태지
# 23                                                서태지
# 24                                    서태지    ,    김종서
# 25                                                양현석
# 26                                                서태지
# 27                                                서태지
# 28                                                서태지
# 29                                                서태지
# ...                                                  ...
# 12660                                           용감한 형제
# 12661            지민 (AOA)   ,   한승훈   ,   서용배 (TENTEN)
# 12662                                     차쿤 (일렉트로보이즈)
# 12663            지민 (AOA)   ,   한승훈   ,   서용배 (TENTEN)
# 12664                                           별들의 전쟁
# 12665                                           용감한 형제
# 12666                              용감한 형제   ,   별들의 전쟁
# 12667                                           용감한 형제
# 12668                              용감한 형제   ,   별들의 전쟁
# 12669                                          Jay Lee
# 12670                        용감한 형제   ,   차쿤 (일렉트로보이즈)
# 12671                        용감한 형제   ,   차쿤 (일렉트로보이즈)
# 12672                    한성호   ,   김도훈 (RBW)   ,   이상호
# 12673                           한승훈   ,   서용배 (TENTEN)
# 12674                               한성호   ,   지민 (AOA)
# 12675                                              김재양
# 12676                                              한성호
# 12677                                              한성호
# 12678                                              김재양
# 12679                                              한성호
# 12680                           정용화 (CNBLUE)   ,   한성호
# 12681                                              한성호
# 12682                           JQ   ,   배성현   ,   현지원
# 12683  대원 (DAEWON)   ,   디알로   ,   필독 (BIGSTAR)   ,  ...
# 12684                   필독 (BIGSTAR)   ,   찬   ,   마르코
# 12685                                              유희열
# 12686  로이도   ,   서재우 (TENTEN)   ,   BreadBeat (TENTEN)
# 12687                 이뮤즈   ,   필독 (BIGSTAR)   ,   마르코
# 12688                                              UNB
# 12689                                    UNB   ,   디알로
#
#                                                 composer  \
# 0                                                 서태지
# 1                                                 서태지
# 2                                                 서태지
# 3                                     서태지    ,    김종서
# 4                                                 서태지
# 5                                                 서태지
# 6                                                 서태지
# 7                                                 서태지
# 8                                                 서태지
# 9                                                 서태지
# 10                                                서태지
# 11                                                서태지
# 12                                                서태지
# 13                                                서태지
# 14                                                서태지
# 15                                                서태지
# 16                                                서태지
# 17                                                   NaN
# 18                                                서태지
# 19                                                서태지
# 20                                                서태지
# 21                                                서태지
# 22                                                서태지
# 23                                                서태지
# 24                                    서태지    ,    김종서
# 25                                                서태지
# 26                                                서태지
# 27                                                서태지
# 28                                                서태지
# 29                                                서태지
# ...                                                  ...
# 12660                               용감한 형제   ,   코끼리왕국
# 12661                           한승훈   ,   서용배 (TENTEN)
# 12662          별들의전쟁   ,   차쿤 (일렉트로보이즈)   ,   Miss Lee
# 12663                           한승훈   ,   서용배 (TENTEN)
# 12664                                 별들의 전쟁   ,   미쓰리
# 12665                               용감한 형제   ,   코끼리왕국
# 12666                              용감한 형제   ,   별들의 전쟁
# 12667                               용감한 형제   ,   코끼리왕국
# 12668                              용감한 형제   ,   별들의 전쟁
# 12669                                              전호진
# 12670           용감한 형제   ,   코끼리 왕국   ,   차쿤 (일렉트로보이즈)
# 12671                              용감한 형제   ,   코끼리 왕국
# 12672                              김도훈 (RBW)   ,   이상호
# 12673                           한승훈   ,   서용배 (TENTEN)
# 12674                                        김도훈 (RBW)
# 12675                                              김재양
# 12676                                               세이
# 12677                                              한승훈
# 12678                                              김재양
# 12679                              김도훈 (RBW)   ,   이상호
# 12680                                     정용화 (CNBLUE)
# 12681                                              김재양
# 12682     LDN Noise   ,   Hayden Chapman   ,   Andy L...
# 12683     디알로   ,   대원 (DAEWON)   ,   De view   ,   원...
# 12684                 필독 (BIGSTAR)   ,   찬   ,   Flame
# 12685                                              유희열
# 12686     서재우 (TENTEN)   ,   BreadBeat (TENTEN)   ,  ...
# 12687     김태성   ,   Maxx Song   ,   Casper   ,   Dell...
# 12688                         필독 (BIGSTAR)   ,   Flame
# 12689                                     디알로   ,   대원
#
#                                          arranger         artist_eng  \
# 0                                          서태지     SeoTaiji And Boys
# 1                                          서태지     SeoTaiji And Boys
# 2                                          서태지     SeoTaiji And Boys
# 3                                          서태지     SeoTaiji And Boys
# 4                                          서태지     SeoTaiji And Boys
# 5                                          서태지     SeoTaiji And Boys
# 6                                          서태지     SeoTaiji And Boys
# 7                                          서태지     SeoTaiji And Boys
# 8                                          서태지     SeoTaiji And Boys
# 9                                          서태지     SeoTaiji And Boys
# 10                                         서태지     SeoTaiji And Boys
# 11                                         서태지     SeoTaiji And Boys
# 12                                         서태지     SeoTaiji And Boys
# 13                                         서태지     SeoTaiji And Boys
# 14                                         서태지     SeoTaiji And Boys
# 15                                         서태지     SeoTaiji And Boys
# 16                                         서태지     SeoTaiji And Boys
# 17                                            NaN  SeoTaiji And Boys
# 18                                         서태지     SeoTaiji And Boys
# 19                                         서태지     SeoTaiji And Boys
# 20                                         서태지     SeoTaiji And Boys
# 12661      6 (8)          지민      여  FNC 엔터테인먼트
# 12662      6 (8)          지민      여  FNC 엔터테인먼트
# 12663      6 (8)          지민      여  FNC 엔터테인먼트
# 12664      6 (8)          지민      여  FNC 엔터테인먼트
# 12665      6 (8)          지민      여  FNC 엔터테인먼트
# 12666      6 (8)          지민      여  FNC 엔터테인먼트
# 12667      6 (8)          지민      여  FNC 엔터테인먼트
# 12668      6 (8)          지민      여  FNC 엔터테인먼트
# 12669      6 (8)          지민      여  FNC 엔터테인먼트
# 12670      6 (8)          지민      여  FNC 엔터테인먼트
# 12671      6 (8)          지민      여  FNC 엔터테인먼트
# 12672      6 (8)          지민      여  FNC 엔터테인먼트
# 12673      6 (8)          지민      여  FNC 엔터테인먼트
# 12674      6 (8)          지민      여  FNC 엔터테인먼트
# 12675      6 (8)          지민      여  FNC 엔터테인먼트
# 12676      6 (8)          지민      여  FNC 엔터테인먼트
# 12677      6 (8)          지민      여  FNC 엔터테인먼트
# 12678      6 (8)          지민      여  FNC 엔터테인먼트
# 12679      6 (8)          지민      여  FNC 엔터테인먼트
# 12680      6 (8)          지민      여  FNC 엔터테인먼트
# 12681      6 (8)          지민      여  FNC 엔터테인먼트
# 12682          9          필독      남   MBK엔터테인먼트
# 12683          9          필독      남   MBK엔터테인먼트
# 12684          9          필독      남   MBK엔터테인먼트
# 12685          9          필독      남   MBK엔터테인먼트
# 12686          9          필독      남   MBK엔터테인먼트
# 12687          9          필독      남   MBK엔터테인먼트
# 12688          9          필독      남   MBK엔터테인먼트
# 12689          9          필독      남   MBK엔터테인먼트
#
# [12690 rows x 16 columns]

# %%
ll = all["lyricist"].tolist

# %%
leader = all["leader_name"].tolist

# %%
# %time leader = all["leader_name"].apply(preprocessing)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-20-9a4c67f08b44> in preprocessing(text)
#       1 def preprocessing(text):
#       2     # 개행문자 제거
# ----> 3     text =  text.strip('\t\n\r')
#       4     pattern = re.compile(r'\s+')
#       5     text = re.sub(pattern, ' ', text)
#
# AttributeError: 'float' object has no attribute 'strip'

# %%
leader
# Out:
# <bound method IndexOpsMixin.tolist of 0        서태지
# 1        서태지
# 2        서태지
# 3        서태지
# 4        서태지
# 5        서태지
# 6        서태지
# 7        서태지
# 8        서태지
# 9        서태지
# 10       서태지
# 11       서태지
# 12       서태지
# 13       서태지
# 14       서태지
# 15       서태지
# 16       서태지
# 17       서태지
# 18       서태지
# 19       서태지
# 20       서태지
# 21       서태지
# 22       서태지
# 23       서태지
# 24       서태지
# 25       서태지
# 26       서태지
# 27       서태지
# 28       서태지
# 29       서태지
#         ...
# 12660     지민
# 12661     지민
# 12662     지민
# 12663     지민
# 12664     지민
# 12665     지민
# 12666     지민
# 12667     지민
# 12668     지민
# 12669     지민
# 12670     지민
# 12671     지민
# 12672     지민
# 12673     지민
# 12674     지민
# 12675     지민
# 12676     지민
# 12677     지민
# 12678     지민
# 12679     지민
# 12680     지민
# 12681     지민
# 12682     필독
# 12683     필독
# 12684     필독
# 12685     필독
# 12686     필독
# 12687     필독
# 12688     필독
# 12689     필독
# Name: leader_name, Length: 12690, dtype: object>

# %%
# %time leader1 = leader.apply(tokenizer.tokenize)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>()
#
# AttributeError: 'function' object has no attribute 'apply'

# %%
song.shape
# Out:
# (12704, 11)

# %%
song.head()
# Out:
#         title    artist                                 album release_date  \
# 0      태지 보이스  서태지와 아이들                            시대유감(時代遺憾)   1996.06.07
# 1  시대유감(時代遺憾)  서태지와 아이들                            시대유감(時代遺憾)   1996.06.07
# 2    수시아(誰是我)  서태지와 아이들                            시대유감(時代遺憾)   1996.06.07
# 3  Free Style  서태지와 아이들                            시대유감(時代遺憾)   1996.06.07
# 4       난 알아요  서태지와 아이들  Seotaji And Boys Good Bye Best Album   1996.02.10
#
#   song_genre is_title   like  \
# 0       Rock      수록곡    269
# 1       Rock    타이틀 곡  3,256
# 2       Rock      수록곡    488
# 3       Rock      수록곡    599
# 4      Dance    타이틀 곡    620
#
#                                               lyrics            lyricist  \
# 0  갈수 없는 곳이란 우리에겐 없어<br>보이는 길밖에도 세상은 있어<br>언제나 식지...              서태지
# 1  왜 기다려 왔잖아<br>모든 삶을 포기하는 소리를<br>이 세상이 모두 미쳐버릴<b...              서태지
# 2  이 세상 그 누구도 나를 닮을 순 없네<br>날 세상에 알릴 거야<br>나 역시 그...              서태지
# 3  항상 난 지나치기만 했네<br>이젠 난 미련없이 끝내<br>됐어 찾아냈어 난<br>...  서태지    ,    김종서
# 4  난 알아요이밤이 흐르고 흐르면 누군가가<br>나를 떠나버려야 한다는 그사실을<br>...              서태지
#
#                  composer    arranger
# 0                  서태지         서태지
# 1                  서태지         서태지
# 2                  서태지         서태지
# 3      서태지    ,    김종서         서태지
# 4                  서태지         서태지

# %%
# !pip install soynlp
# !pip show soynlp
# Out:
# Requirement already satisfied: soynlp in /Users/yunkim/anaconda3/lib/python3.6/site-packages (0.0.46)
# Requirement already satisfied: psutil>=5.0.1 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from soynlp) (5.4.5)
# Requirement already satisfied: numpy>=1.12.1 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from soynlp) (1.14.3)
# Name: soynlp
# Version: 0.0.46
# Summary: Unsupervised Korean Natural Language Processing Toolkits
# Home-page: https://github.com/lovit/soynlp
# Author: Lovit
# Author-email: soy.lovit@gmail.com
# License: UNKNOWN
# Location: /Users/yunkim/anaconda3/lib/python3.6/site-packages
# Requires: psutil, numpy
# Required-by:

# %%
# !pip install gensim
# !pip show gensim
# Out:
# Requirement already satisfied: gensim in /Users/yunkim/anaconda3/lib/python3.6/site-packages (3.5.0)
# Requirement already satisfied: scipy>=0.18.1 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from gensim) (1.1.0)
# Requirement already satisfied: smart-open>=1.2.1 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from gensim) (1.6.0)
# Requirement already satisfied: numpy>=1.11.3 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from gensim) (1.14.3)
# Requirement already satisfied: six>=1.5.0 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from gensim) (1.11.0)
# Requirement already satisfied: boto>=2.32 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (2.48.0)
# Requirement already satisfied: bz2file in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (0.98)
# Requirement already satisfied: requests in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (2.18.4)
# Requirement already satisfied: boto3 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (1.9.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim) (2018.4.16)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from boto3->smart-open>=1.2.1->gensim) (0.1.13)
# Requirement already satisfied: botocore<1.13.0,>=1.12.0 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from boto3->smart-open>=1.2.1->gensim) (1.12.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from boto3->smart-open>=1.2.1->gensim) (0.9.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.0->boto3->smart-open>=1.2.1->gensim) (2.7.3)
# Requirement already satisfied: docutils>=0.10 in /Users/yunkim/anaconda3/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.0->boto3->smart-open>=1.2.1->gensim) (0.14)
# Name: gensim
# Version: 3.5.0
# Summary: Python framework for fast Vector Space Modelling
# Home-page: http://radimrehurek.com/gensim
# Author: Radim Rehurek
# Author-email: me@radimrehurek.com
# License: LGPLv2.1
# Location: /Users/yunkim/anaconda3/lib/python3.6/site-packages
# Requires: six, smart-open, scipy, numpy
# Required-by:

# %%
import numpy as np
import re

# %%
from soynlp.tokenizer import RegexTokenizer

tokenizer = RegexTokenizer()
tokenizer

# %%
female = all[all['gender'] == '여']
female
# Out:
#                               title artist  \
# 108                     이제는 바꿀수 있어요  에스오에스
# 109                       처음 느낌 그대로  에스오에스
# 110                            발렌타인  에스오에스
# 111                         하지만...넌  에스오에스
# 112                           너의 바보  에스오에스
# 1866                            천사표    쎄쎄쎄
# 1867                        언제나 네곁에    쎄쎄쎄
# 1868                           오락가락    쎄쎄쎄
# 1869                       Next Day    쎄쎄쎄
# 1870                        넌 성공한거야    쎄쎄쎄
# 1871                           와뚜와리    쎄쎄쎄
# 1872                             엑스    쎄쎄쎄
# 1873                      안봐도 Video    쎄쎄쎄
# 1874                           Over    쎄쎄쎄
# 1875                           떠날거야    쎄쎄쎄
# 1876            신데렐라 컴플렉스 (온달에게 고함)    쎄쎄쎄
# 1877                      아미가르 레스토랑    쎄쎄쎄
# 1878                          부메랑처럼    쎄쎄쎄
# 1879                        루즈의 메세지    쎄쎄쎄
# 1880                      썰렁한 걸 모르니    쎄쎄쎄
# 1881                     Candy Lane  에스이에스
# 1882                       Remember  에스이에스
# 1883             한 폭의 그림 (Paradise)  에스이에스
# 1884                       Birthday  에스이에스
# 1885        My Rainbow (친구-세번째 이야기)  에스이에스
# 1886                           Hush  에스이에스
# 1887       산다는 건 다 그런 게 아니겠니 (Life)  에스이에스
# 1888   그대로부터 세상 빛은 시작되고 (The Light)  에스이에스
# 1889                   Love [story]  에스이에스
# 1890                   Love [story]  에스이에스
# ...                             ...    ...
# 12652            심쿵해 (Heart Attack)  에이오에이
# 12653                        Luv me  에이오에이
# 12654              들어와 (Come To Me)  에이오에이
# 12655               한 개 (One Thing)  에이오에이
# 12656            진짜 (Really Really)  에이오에이
# 12657                     Chocolate  에이오에이
# 12658                           AOA  에이오에이
# 12659                          사뿐사뿐  에이오에이
# 12660                         여자사용법  에이오에이
# 12661                           단둘이  에이오에이
# 12662                          Time  에이오에이
# 12663                           휠릴리  에이오에이
# 12664                       Fantasy  에이오에이
# 12665             단발머리 (Short Hair)  에이오에이
# 12666                       Joa YO!  에이오에이
# 12667                          내 반쪽  에이오에이
# 12668                       말이 안 통해  에이오에이
# 12669               그대, 승리의 날개를 펼쳐라  에이오에이
# 12670             짧은 치마 (Miniskirt)  에이오에이
# 12652              용감한 형제   ,   차쿤 (일렉트로보이즈)
# 12653                                 용감한 형제
# 12654  한승훈   ,   지민 (AOA)   ,   서용배 (TENTEN)
# 12655              용감한 형제   ,   차쿤 (일렉트로보이즈)
# 12656              용감한 형제   ,   차쿤 (일렉트로보이즈)
# 12657                                 별들의 전쟁
# 12658                                 용감한 형제
# 12659              용감한 형제   ,   차쿤 (일렉트로보이즈)
# 12660                                 용감한 형제
# 12661  지민 (AOA)   ,   한승훈   ,   서용배 (TENTEN)
# 12662                           차쿤 (일렉트로보이즈)
# 12663  지민 (AOA)   ,   한승훈   ,   서용배 (TENTEN)
# 12664                                 별들의 전쟁
# 12665                                 용감한 형제
# 12666                    용감한 형제   ,   별들의 전쟁
# 12667                                 용감한 형제
# 12668                    용감한 형제   ,   별들의 전쟁
# 12669                                Jay Lee
# 12670              용감한 형제   ,   차쿤 (일렉트로보이즈)
# 12671              용감한 형제   ,   차쿤 (일렉트로보이즈)
# 12672          한성호   ,   김도훈 (RBW)   ,   이상호
# 12673                 한승훈   ,   서용배 (TENTEN)
# 12674                     한성호   ,   지민 (AOA)
# 12675                                    김재양
# 12676                                    한성호
# 12677                                    한성호
# 12678                                    김재양
# 12679                                    한성호
# 12680                 정용화 (CNBLUE)   ,   한성호
# 12681                                    한성호
#
#                                                 composer  \
# 108                                                  NaN
# 109                                                  NaN
# 110                                                  NaN
# 111                                                  NaN
# 112                                                  NaN
# 1866                                                 NaN
# 1867                                                 NaN
# 1868                                                 NaN
# 1869                                                 NaN
# 1870                                                 NaN
# 1871                                                 NaN
# 1872                                                 NaN
# 1873                                                 NaN
# 1874                                                 NaN
# 1875                                                 NaN
# 1876                                                 NaN
# 1877                                                 NaN
# 1878                                                 NaN
# 1879                                                 NaN
# 1880                                                 NaN
# 1881       추대관 (MonoTree)    ,    Felicia Barton    ,...
# 1882       Erik Lidbom    ,    Fast Lane    ,    Lisa...
# 1883       유영진    ,    Mike Daley    ,    Mitchell Ow...
# 1884                   G-High (MonoTree)    ,    신아녜스
# 1885       Carolyn Jordan    ,    Mats Ymell    ,    ...
# 1886       Teddy Riley    ,    이현승    ,    DOM    ,  ...
# 1887                                              조병석
# 1888                                              홍종화
# 1889                                              유영진
# 1890                                              유영진
# ...                                                  ...
# 12652             용감한 형제   ,   MR.강   ,   차쿤 (일렉트로보이즈)
# 12653                                  용감한 형제   ,   js
# 12654                           한승훈   ,   서용배 (TENTEN)
# 12655           용감한 형제   ,   별들의 전쟁   ,   차쿤 (일렉트로보이즈)
# 12656                               용감한 형제   ,   코끼리왕국
# 12657                            별들의 전쟁   ,   Miss Lee
# 12658                                용감한 형제   ,   똘아이박
# 12659               용감한 형제   ,   차쿤 (일렉트로보이즈)   ,   JS
# 12660                               용감한 형제   ,   코끼리왕국
# 12661                           한승훈   ,   서용배 (TENTEN)
# 12662          별들의전쟁   ,   차쿤 (일렉트로보이즈)   ,   Miss Lee
# 12663                           한승훈   ,   서용배 (TENTEN)
# 12664                                 별들의 전쟁   ,   미쓰리
# 12665                               용감한 형제   ,   코끼리왕국
# 12666                              용감한 형제   ,   별들의 전쟁
# 12667                               용감한 형제   ,   코끼리왕국
# 12668                              용감한 형제   ,   별들의 전쟁
# 12669                                              전호진
# 12670           용감한 형제   ,   코끼리 왕국   ,   차쿤 (일렉트로보이즈)
# 12671                              용감한 형제   ,   코끼리 왕국
# 12672                              김도훈 (RBW)   ,   이상호
# 12673                           한승훈   ,   서용배 (TENTEN)
# 12674                                        김도훈 (RBW)
# 12675                                              김재양
# 12676                                               세이
# 12677                                              한승훈
# 12678                                              김재양
# 12679                              김도훈 (RBW)   ,   이상호
# 12680                                     정용화 (CNBLUE)
# 12681                                              김재양
#
#                                                 arranger artist_eng  \
# 108                                                  NaN      S.O.S
# 109                                                  NaN      S.O.S
# 110                                                  NaN      S.O.S
# 111                                                  NaN      S.O.S
# 112                                                  NaN      S.O.S
# 1866                                                 NaN   Se Se Se
# 1867                                                 NaN   Se Se Se
# 1868                                                 NaN   Se Se Se
# 1869                                                 NaN   Se Se Se
# 1870                                                 NaN   Se Se Se
# 1871                                                 NaN   Se Se Se
# 1872                                                 NaN   Se Se Se
# 1873                                                 NaN   Se Se Se
# 1874                                                 NaN   Se Se Se
# 1875                                                 NaN   Se Se Se
# 1876                                                 NaN   Se Se Se
# 1877                                                 NaN   Se Se Se
# 1878                                                 NaN   Se Se Se
# 1879                                                 NaN   Se Se Se
# 1880                                                 NaN   Se Se Se
# 1881                                   추대관 (MonoTree)        S.E.S.
# 1882                                      Erik Lidbom        S.E.S.
# 1883       유영진    ,    Mike Daley    ,    Mitchell Ow...     S.E.S.
# 1884                                G-High (MonoTree)        S.E.S.
# 1885                                       Mats Ymell        S.E.S.
# 1886       Teddy Riley    ,    이현승    ,    DOM    ,  ...     S.E.S.
# 1887                                               황현        S.E.S.
# 1888                                  유영진    ,    유한진        S.E.S.
# 1889                                              유한진        S.E.S.
# 1890                                              유한진        S.E.S.
# ...                                                  ...        ...
# 12652                     용감한 형제   ,   코끼리왕국   ,   이정민          AOA
# 12653                                  코끼리왕국   ,   이정민          AOA
# 12654                                     서용배 (TENTEN)          AOA
# 12655                                           별들의 전쟁          AOA
# 12656                                  코끼리왕국   ,   이정민          AOA
# 12657                                         Miss Lee          AOA
# 12658                                             똘아이박          AOA
# 12659                             용감한 형제   ,   Mr.Kang          AOA
# 12660                     용감한 형제   ,   코끼리왕국   ,   이정민          AOA
# 12661                                     서용배 (TENTEN)          AOA
# 12662                             별들의전쟁   ,   Miss Lee          AOA
# 12663                                     서용배 (TENTEN)          AOA
# 12664                                 별들의 전쟁   ,   미쓰리          AOA
# 12665                               용감한 형제   ,   코끼리왕국          AOA
# 12666                                           별들의 전쟁          AOA
# 12667                     용감한 형제   ,   코끼리왕국   ,   이정민          AOA
# 12668                                           별들의 전쟁          AOA
# 12669                                              전호진          AOA
# 12670                    용감한 형제   ,   코끼리 왕국   ,   이정민          AOA
# 12671                                 코끼리 왕국   ,   이정민          AOA
# 12672                              김도훈 (RBW)   ,   이상호          AOA
# 12673                           한승훈   ,   서용배 (TENTEN)          AOA
# 12674                              김도훈 (RBW)   ,   최용찬          AOA
# 12675                                              김재양          AOA
# 12676                                              이상호          AOA
# 12677                                              한승훈          AOA
# 12678                                              김재양          AOA
# 12679                                              이상호          AOA
# 12680                           이상호   ,   서용배 (TENTEN)          AOA
# 12681                                              김재양          AOA
#
#       member_num leader_name gender      agency
# 108            4         NaN      여     삼포니 레코드
# 109            4         NaN      여     삼포니 레코드
# 110            4         NaN      여     삼포니 레코드
# 111            4         NaN      여     삼포니 레코드
# 112            4         NaN      여     삼포니 레코드
# 1866           3         NaN      여        희레코드
# 1867           3         NaN      여        희레코드
# 1868           3         NaN      여        희레코드
# 1869           3         NaN      여        희레코드
# 1870           3         NaN      여        희레코드
# 1871           3         NaN      여        희레코드
# 1872           3         NaN      여        희레코드
# 1873           3         NaN      여        희레코드
# 1874           3         NaN      여        희레코드
# 1875           3         NaN      여        희레코드
# 1876           3         NaN      여        희레코드
# 1877           3         NaN      여        희레코드
# 1878           3         NaN      여        희레코드
# 1879           3         NaN      여        희레코드
# 1880           3         NaN      여        희레코드
# 1881           3          바다      여   SM 엔터테인먼트
# 1882           3          바다      여   SM 엔터테인먼트
# 1883           3          바다      여   SM 엔터테인먼트
# 1884           3          바다      여   SM 엔터테인먼트
# 1885           3          바다      여   SM 엔터테인먼트
# 1886           3          바다      여   SM 엔터테인먼트
# 1887           3          바다      여   SM 엔터테인먼트
# 1888           3          바다      여   SM 엔터테인먼트
# 1889           3          바다      여   SM 엔터테인먼트
# 1890           3          바다      여   SM 엔터테인먼트
# ...          ...         ...    ...         ...
# 12652      6 (8)          지민      여  FNC 엔터테인먼트
# 12653      6 (8)          지민      여  FNC 엔터테인먼트
# 12654      6 (8)          지민      여  FNC 엔터테인먼트
# 12655      6 (8)          지민      여  FNC 엔터테인먼트
# 12656      6 (8)          지민      여  FNC 엔터테인먼트
# 12657      6 (8)          지민      여  FNC 엔터테인먼트
# 12658      6 (8)          지민      여  FNC 엔터테인먼트
# 12659      6 (8)          지민      여  FNC 엔터테인먼트
# 12660      6 (8)          지민      여  FNC 엔터테인먼트
# 12661      6 (8)          지민      여  FNC 엔터테인먼트
# 12662      6 (8)          지민      여  FNC 엔터테인먼트
# 12663      6 (8)          지민      여  FNC 엔터테인먼트
# 12664      6 (8)          지민      여  FNC 엔터테인먼트
# 12665      6 (8)          지민      여  FNC 엔터테인먼트
# 12666      6 (8)          지민      여  FNC 엔터테인먼트
# 12667      6 (8)          지민      여  FNC 엔터테인먼트
# 12668      6 (8)          지민      여  FNC 엔터테인먼트
# 12669      6 (8)          지민      여  FNC 엔터테인먼트
# 12670      6 (8)          지민      여  FNC 엔터테인먼트
# 12671      6 (8)          지민      여  FNC 엔터테인먼트
# 12672      6 (8)          지민      여  FNC 엔터테인먼트
# 12673      6 (8)          지민      여  FNC 엔터테인먼트
# 12674      6 (8)          지민      여  FNC 엔터테인먼트
# 12675      6 (8)          지민      여  FNC 엔터테인먼트
# 12628    타이틀 곡    475  Oh Oh Oh Oh<br>I Wanna Make You My Girlfriend<...
# 12629      수록곡    332  내게는 너 말고 딴 사람은 없어<br>미안해 이렇게 보내지 못해<br>벗어날수 없어...
# 12630      수록곡  1,291  널 향한 메세지<br>뜨거운 마음을<br>가득 눌러 담아서<br>지금 네게 보낸다<...
# 12682    타이틀 곡  5,758  Hoo<br>Yeah hey hey hey c'mon<br>La dda dda dd...
# 12683      수록곡  1,355  창밖에 내리는 빗소리<br>흐르는 시간처럼<br>빗물은 흘러내리네<br>내린 빗방울...
# 12684      수록곡  1,180  저 달빛 아래 너와 나<br>손잡고 같이 걸을까 babe<br>나 꿈을 꾸는 것 같...
# 12685     인기 곡  2,383  그랬나봐 나 널 좋아하나봐<br>하루하루 니 생각만 나는 걸<br>널 보고 싶다고 ...
# 12686     인기 곡  9,165  떨리는 눈빛이 보여<br>알아 니 마음 I Feel ya<br>첨으로 느껴본 감정<...
# 12687      수록곡  4,773  시린 겨울 밤이 지나고<br>흩날리는 꽃잎 사이로<br>지쳐있던 내게로 니가 불어와...
# 12688      수록곡  1,982  일단 올라타 babe<br>이건 꿈같아 되게<br>니가 가고 싶은 곳 편하게 말해줘...
# 12689      수록곡  1,906  난 꿈이 있지<br>오늘도 오늘도 오늘도 Yah<br>내일도 내일도 내일도 Yah<...
#
#                                                 lyricist  \
# 0                                                 서태지
# 1                                                 서태지
# 2                                                 서태지
# 3                                     서태지    ,    김종서
# 4                                                 서태지
# 5                                                 서태지
# 6                                                 서태지
# 7                                                 서태지
# 8                            서태지    ,    WILLIAM BYUN
# 9                                                 서태지
# 10                                                서태지
# 11                                                서태지
# 12                                                서태지
# 13                                                서태지
# 14                                                서태지
# 15                                                서태지
# 16                                                서태지
# 17                                                   NaN
# 18                                                서태지
# 19                                                서태지
# 20                                                서태지
# 21                                                서태지
# 22                                                서태지
# 23                                                서태지
# 24                                    서태지    ,    김종서
# 25                                                양현석
# 26                                                서태지
# 27                                                서태지
# 28                                                서태지
# 29                                                서태지
# ...                                                  ...
# 12609                            디파이   ,   세용   ,   준Q
# 12610                                       BlueBridge
# 12611                        이현도   ,   TKO   ,   Eniac
# 12612                        이현도   ,   TKO   ,   Eniac
# 12613                                    이현도   ,   TKO
# 12614                          e.one   ,   준Q   ,   세용
# 12615                        이현도   ,   TKO   ,   Eniac
# 12616                                   똘아이박   ,   피터팬
# 12617                                            Roxta
# 12618                                    임광욱   ,   김창락
# 12619                                e.one   ,   VanAn
# 12620                                            VanAn
# 12621                          똘아이박   ,   마부스 (Maboos)
# 12622                                   e.one   ,   준Q
# 12623                           송양하   ,   김유석   ,   미풍
# 12624                                               환희
# 12625                                    구자경   ,   이호승
# 12626                                           제이 슬로우
# 12627                                    구자경   ,   이호승
# 12628                                    Urban Cllasik
# 12629                                               환희
# 12630                                                NaN
# 12682                           JQ   ,   배성현   ,   현지원
# 12683  대원 (DAEWON)   ,   디알로   ,   필독 (BIGSTAR)   ,  ...
# 12684                   필독 (BIGSTAR)   ,   찬   ,   마르코
# 12685                                              유희열
# 12686  로이도   ,   서재우 (TENTEN)   ,   BreadBeat (TENTEN)
# 12687                 이뮤즈   ,   필독 (BIGSTAR)   ,   마르코
# 12688                                              UNB
# 12689                                    UNB   ,   디알로
#
#                                                 composer  \
# 0                                                 서태지
# 1                                                 서태지
# 2                                                 서태지
# 3                                     서태지    ,    김종서
# 4                                                 서태지
# 5                                                 서태지
# 6                                                 서태지
# 7                                                 서태지
# 8                                                 서태지
# 9                                                 서태지
# 10                                                서태지
# 11                                                서태지
# 12                                                서태지
# 13                                                서태지
# 14                                                서태지
# 15                                                서태지
# 16                                                서태지
# 17                                                   NaN
# 18                                                서태지
# 19                                                서태지
# 20                                                서태지
# 21                                                서태지
# 22                                                서태지
# 23                                                서태지
# 24                                    서태지    ,    김종서
# 25                                                서태지
# 26                                                서태지
# 27                                                서태지
# 28                                                서태지
# 29                                                서태지
# ...                                                  ...
# 12609                                      ZigZag Note
# 12610                                       BlueBridge
# 12611                                  이현도   ,   Eniac
# 12612                                  이현도   ,   Eniac
# 12613                                  이현도   ,   Eniac
# 12614                                            e.one
# 12615                                  이현도   ,   Eniac
# 12616                                   똘아이박   ,   피터팬
# 12617                                            Roxta
# 12618                                    임광욱   ,   김창락
# 12619                                            e.one
# 12620                                            e.one
# 12621                                             똘아이박
# 12622                                            e.one
# 12623                                    송양하   ,   김유석
# 12624                                     이치우   ,   환희
# 12625                                    구자경   ,   이호승
# 12626                                    구자경   ,   이호승
# 12627                                    구자경   ,   이호승
# 12628                          이경봉   ,   Urban Cllasik
# 12629                                              이치우
# 12630                                                NaN
# 12682     LDN Noise   ,   Hayden Chapman   ,   Andy L...
# 12683     디알로   ,   대원 (DAEWON)   ,   De view   ,   원...
# 12684                 필독 (BIGSTAR)   ,   찬   ,   Flame
# 12685                                              유희열
# 12686     서재우 (TENTEN)   ,   BreadBeat (TENTEN)   ,  ...
# 12687     김태성   ,   Maxx Song   ,   Casper   ,   Dell...
# 12688                         필독 (BIGSTAR)   ,   Flame
# 12689                                     디알로   ,   대원
#
#                                          arranger         artist_eng  \
# 0                                          서태지     SeoTaiji And Boys
# 1                                          서태지     SeoTaiji And Boys
# 2                                          서태지     SeoTaiji And Boys
# 3                                          서태지     SeoTaiji And Boys
# 4                                          서태지     SeoTaiji And Boys
# 5                                          서태지     SeoTaiji And Boys
# 6                                          서태지     SeoTaiji And Boys
# 7                                          서태지     SeoTaiji And Boys
# 8                                          서태지     SeoTaiji And Boys
# 9                                          서태지     SeoTaiji And Boys
# 10                                         서태지     SeoTaiji And Boys
# 11                                         서태지     SeoTaiji And Boys
# 12                                         서태지     SeoTaiji And Boys
# 13                                         서태지     SeoTaiji And Boys
# 14                                         서태지     SeoTaiji And Boys
# 15                                         서태지     SeoTaiji And Boys
# 16                                         서태지     SeoTaiji And Boys
# 17                                            NaN  SeoTaiji And Boys
# 18                                         서태지     SeoTaiji And Boys
# 19                                         서태지     SeoTaiji And Boys
# 20                                         서태지     SeoTaiji And Boys
# 21                                         서태지     SeoTaiji And Boys
# 22                                         서태지     SeoTaiji And Boys
# 23                                         서태지     SeoTaiji And Boys
# 24                                         서태지     SeoTaiji And Boys
# 25                                         서태지     SeoTaiji And Boys
# 26                                         서태지     SeoTaiji And Boys
# 27                                         서태지     SeoTaiji And Boys
# 28                                         서태지     SeoTaiji And Boys
# 29                                         서태지     SeoTaiji And Boys
# ...                                           ...                ...
# 12609                               ZigZag Note               MYNAME
# 12610                                BlueBridge               MYNAME
# 12611                           이현도   ,   Eniac               MYNAME
# 12612                           이현도   ,   Eniac               MYNAME
# 12613                           이현도   ,   Eniac               MYNAME
# 12614                                     e.one               MYNAME
# 12615                           이현도   ,   Eniac               MYNAME
# 12616                                      똘아이박               MYNAME
# 12617                                     Roxta               MYNAME
# 12618                                       임광욱               MYNAME
# 12619                                     e.one               MYNAME
# 12620                                     e.one               MYNAME
# 12621                                      똘아이박               MYNAME
# 12622                                     e.one               MYNAME
# 12623                             송양하   ,   김유석               MYNAME
# 12624                                       이치우               MYNAME
# 12625                             구자경   ,   이호승               MYNAME
# 12626                             구자경   ,   이호승               MYNAME
# 12627                                       김진환               MYNAME
# 12628                   이경봉   ,   Urban Cllasik               MYNAME
# 12629                                       이치우               MYNAME
# 12630                                         NaN             MYNAME
# 12682              LDN Noise   ,   Ryan S. Jhun                  UNB
# 12683               De view   ,   원선재   ,   정나현                  UNB
# 12684                                     Flame                  UNB
# 12685                                    DJ PLO                  UNB
# 12686     서재우 (TENTEN)   ,   BreadBeat (TENTEN)                  UNB
# 12687                                 Delly Boi                  UNB
# 12688                                     Flame                  UNB
# 12689                                       디알로                  UNB
#
#       member_num leader_name gender     agency
# 0              3         서태지      남      요요 기획
# 1              3         서태지      남      요요 기획
# 2              3         서태지      남      요요 기획
# 3              3         서태지      남      요요 기획
# 4              3         서태지      남      요요 기획
# 5              3         서태지      남      요요 기획
# 6              3         서태지      남      요요 기획
# 7              3         서태지      남      요요 기획
# 8              3         서태지      남      요요 기획
# 9              3         서태지      남      요요 기획
# 10             3         서태지      남      요요 기획
# 11             3         서태지      남      요요 기획
# 12             3         서태지      남      요요 기획
# 13             3         서태지      남      요요 기획
# 14             3         서태지      남      요요 기획
# 15             3         서태지      남      요요 기획
# 16             3         서태지      남      요요 기획
# 17             3         서태지      남      요요 기획
# 18             3         서태지      남      요요 기획
# 19             3         서태지      남      요요 기획
# 20             3         서태지      남      요요 기획
# 21             3         서태지      남      요요 기획
# 22             3         서태지      남      요요 기획
# 23             3         서태지      남      요요 기획
# 24             3         서태지      남      요요 기획
# 25             3         서태지      남      요요 기획
# 26             3         서태지      남      요요 기획
# 27             3         서태지      남      요요 기획
# 28             3         서태지      남      요요 기획
# 29             3         서태지      남      요요 기획
# ...          ...         ...    ...        ...
# 12609          5         이건우      남   에이치투 미디어
# 12610          5         이건우      남   에이치투 미디어
# 12611          5         이건우      남   에이치투 미디어
# 12612          5         이건우      남   에이치투 미디어
# 12613          5         이건우      남   에이치투 미디어
# 12614          5         이건우      남   에이치투 미디어
# 12615          5         이건우      남   에이치투 미디어
# 12616          5         이건우      남   에이치투 미디어
# 12617          5         이건우      남   에이치투 미디어
# 12618          5         이건우      남   에이치투 미디어
# 12619          5         이건우      남   에이치투 미디어
# 12620          5         이건우      남   에이치투 미디어
# 12621          5         이건우      남   에이치투 미디어
# 12622          5         이건우      남   에이치투 미디어
# 12623          5         이건우      남   에이치투 미디어
# 12624          5         이건우      남   에이치투 미디어
# 12625          5         이건우      남   에이치투 미디어
# 12626          5         이건우      남   에이치투 미디어
# 12627          5         이건우      남   에이치투 미디어
# 12628          5         이건우      남   에이치투 미디어
# 12629          5         이건우      남   에이치투 미디어
# 12630          5         이건우      남   에이치투 미디어
# 12682          9          필독      남  MBK엔터테인먼트
# 12683          9          필독      남  MBK엔터테인먼트
# 12684          9          필독      남  MBK엔터테인먼트
# 12685          9          필독      남  MBK엔터테인먼트
# 12686          9          필독      남  MBK엔터테인먼트
# 12687          9          필독      남  MBK엔터테인먼트
# 12688          9          필독      남  MBK엔터테인먼트
# 12689          9          필독      남  MBK엔터테인먼트
#
# [7949 rows x 16 columns]

# %%
# song2 = pd.read_csv

# %%
def preprocessing(text):
    # 개행문자 제거
#     text = re.sub('\\\\n', ' ', text)
    # 특수문자 제거
    # 특수문자나 이모티콘 등은 때로는 의미를 갖기도 하지만 여기에서는 제거했습니다.
    text = re.sub('[?.,;:|\)*~`’!^\-_+<>@\#$%&-=#}※]', '', text)
#     text = re.sub('[\\r\\n]', ' ', text)
    # text = re.sub('[0-9]', '', text)
    # 한글, 영문, 숫자만 남기고 모두 제거하도록 합니다.
    # text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z0-9]', ' ', text)
    # 한글, 영문만 남기고 모두 제거하도록 합니다.
    text = re.sub('[0-9]', ' ', text)
    return text

# %%
def preprocessing(text):
    # 개행문자 제거
    text =  text.strip('\t\n\r')
    pattern = re.compile(r'\s+')
    text = re.sub(pattern, ' ', text)
    # 특수문자 제거
    # 특수문자나 이모티콘 등은 때로는 의미를 갖기도 하지만 여기에서는 제거했습니다.
    # text = re.sub('[?.,;:|\)*~`’!^\-_+<>@\#$%&-=#}※]', '', text)
    # 한글, 영문, 숫자만 남기고 모두 제거하도록 합니다.
    # text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z0-9]', ' ', text)
    # 한글, 영문만 남기고 모두 제거하도록 합니다.
    text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z]', ' ', text)
    return text

# %%
male['lyrics'] = male['lyrics'].str.replace(r'<br>', ' ')
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
female['lyrics'] = female['lyrics'].str.replace(r'<br>', ' ')
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# %time을 찍어주면 해당 코드를 실행할 때 걸리는 시간을 출력해 줍니다
# %time sentences = female['lyrics'].apply(preprocessing)
# Out:
# CPU times: user 870 ms, sys: 20.8 ms, total: 890 ms
# Wall time: 985 ms

# %%
# %time sentences2 = male['lyrics'].apply(preprocessing)
# Out:
# CPU times: user 1.47 s, sys: 31.8 ms, total: 1.5 s
# Wall time: 1.59 s

# %%
sentences
# Out:
# 108      간직하고픈 꿈 있는 친구여 푸른 바다와 하늘을 보아요 때론 실의와 고뇌에 잠들어 어...
# 1889     Baby always brand new 너의 사랑만큼 나를 행복하게 해주는 건 없는...
# 1890     Baby always brand new 너의 사랑만큼 나를 행복하게 해주는 건 없는...
#                                ...
# 12652    A ye Brave sound And it goes a little somethin...
# 12653    Do it this do it this girl Do it this do it th...
# 12654    요즘 남자들 모두 똑같아 뻔한 그 말들 너무 식상해 원하는 대로 바라는 대로 빙빙 ...
# 12655    딱 하루만 더 내게 시간을 줘 우리 내일 다시 헤어지자고 너와 끼던 반지 한 개 아...
# 12656    Since you left me I feel so cold and all alone...
# 12657    Sweetest sweetest Sweetest sweetest chocolate ...
# 12658    My fans My everything We got you back Just don...
# 12659    Hey no matter where you go 그 어딜 봐도 The pretty ...
# 12660    Eh eh eh eh eh eh 에에에 에에에 AOA Eh eh eh eh eh e...
# 12661    Just the two of us 너의 손길 느낌이 좋아 너의 시선 느낌이 좋아 떨...
# 12662    오늘도 밤이 깊어서야 눈을 뜨고 세수를 하다 거울을 보고 부어있는 두 눈 입가에 쓴...
# 12663    오늘 하루도 울다 잠들죠 그대 기억에 지쳐 잠들죠 안 된다고 날 타일러봐도 눈물로 ...
# 12664    G thangs All you gotta do is dreamin  Just 꿈 꿔...
# 12665    Hey Hey Hey Gonna be alright right right Hey H...
# 12666    shu bi du bi la baba shu bi du bi la baba shu ...
# 12667    It s Brave Sound And AOA 나에게서 가져간 내 반 쪽 행복하니 넌...
# 12668    G thangs Sorry girl but I have to say this Don...
# 12669    오오 오오오 오오오 그대 승리의 날개를 펼쳐라 오오 오오오 오오오 put your ...
# 12670    Hey Hey Hey AOA Hey Hey Hey Brave Sound Drop i...
# 12671    hoo 기억나니 baby 가로등 불 아래 우리 사랑했던 그때 baby I miss ...
# 12672    Boy keeps me foolin  in love Yeah you made me ...
# 12673    한 줄기 햇살이 내 잠을 깨우고 한가득 입가에 웃음이 번지고 기다렸었던 약속했던 그...
# 12674    A to the O to the huh uh AA Yeah How could you...
# 12675    노을빛 아름답던 어느 날에 수줍게 내게 다가와 바람결에 스치듯 속삭였지 Everyd...
# 12676    필요 없어 I will kick you ah ah ah I wanna say goo...
# 12677    내겐 네가 제일 멋지고 내겐 네가 제일 든든해 난 네가 정말 그래 너는 내가 제일 ...
# 12678    Can you hear Can you hear Can you hear my musi...
# 12679    웬일이야 미쳤나 봐 숨이 막혀와 온몸이 다 충격이야 찌릿 찌릿해 발소리 똑각 똑각 ...
# 12680    Love is only you Love is only you Love is only...
# 12681    너의 달콤했던 속삭임에 속아 그저 황홀했던 유혹들에 속아 내가 쓰러져 내가 망가져 ...
# Name: lyrics, Length: 4025, dtype: object

# %%
# match = re.search(r'나', str)

# %%
# p = re.compile("^나*")
# result = p.findall(str(sentences))
# result

# %%
# r = re.compile("^나*")
# Im = filter(r.match, sentences)
# Im

# %%
from soynlp.tokenizer import RegexTokenizer
import gensim
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence
from gensim import corpora, models
from gensim.models import LdaMulticore
from gensim.models import Word2Vec
from gensim.corpora import Dictionary, MmCorpus


tokenizer = RegexTokenizer()
tokenizer

# %%
# %time tokens = sentences.apply(tokenizer.tokenize)
# Out:
# CPU times: user 6.66 s, sys: 102 ms, total: 6.76 s
# Wall time: 6.89 s

# %%
# %time tokens2 = sentences2.apply(tokenizer.tokenize)
# Out:
# CPU times: user 14.7 s, sys: 276 ms, total: 14.9 s
# Wall time: 16.2 s

# %%
# berry_idx = [i for i, item in enumerate(sentences2) if item.endswith('없다')]
# berry_idx

# %%
# sentences = sentences.tolist()

# %%
sentences = list( map(str, sentences) )

# %%
sentences2 = list( map(str, sentences2) )

# %%
# 두 음절 이상으로 묶어준다.
more_words = []
for i in tokens:
    for v in i :
        if len(v) > 1:
            more_words.append(v)

# %%
more_words
# Out:
# ['간직하고픈',
#  '있는',
#  '친구여',
#  '푸른',
#  '바다와',
#  '하늘을',
#  '보아요',
#  '때론',
#  '실의와',
#  '고뇌에',
#  '잠들어',
#  '어둔',
#  '빛으로',
#  '없잖아요',
#  '세상은',
#  '오늘만으로',
#  '끝이',
#  '나는건',
#  '아니예요',
#  '이젠',
#  '눈물을',
#  '닦아요',
#  '내일은',
#  '다시',
#  '우리에게',
#  '타오르는',
#  '태양과',
#  '부신',
#  '기쁜',
#  '날들로',
#  '이제는',
#  '바꿀',
#  '있어요',
#  '어둠은',
#  '걷히고',
#  '나의',
#  '길을',
#  '향하여',
#  '어떤',
#  '때에는',
#  '너무',
#  '힘이',
#  '들어',
#  '누군가',
#  '내게',
#  '있기를',
#  '원했죠',
#  '하지만',
#  '이젠',
#  '언제나',
#  '그렇게',
#  '후회를',
#  '하며',
#  '없잖아요',
#  '세상은',
#  '오늘만으로',
#  '끝이',
#  '나는건',
#  '아니예요',
#  '이젠',
#  '눈물을',
#  '닦아요',
#  '내일은',
#  '다시',
#  '우리에게',
#  '어둠에',
#  '지친',
#  '과거와',
#  '내일의',
#  '밝은',
#  '미소로',
#  '이제는',
#  '바꿀',
#  '있어요',
#  '다시',
#  '일어나',
#  '나의',
#  '길을',
#  '향하여',
#  '내일은',
#  '다시',
#  '우리에게',
#  '타오르는',
#  '태양과',
#  '부신',
#  '기쁜',
#  '날들로',
#  '이제는',
#  '바꿀',
#  '있어요',
#  '어둠은',
#  '걷히고',
#  '나의',
#  '길을',
#  '향하여',
#  '내일은',
#  '다시',
#  '우리에게',
#  '어둠에',
#  '지친',
#  '과거와',
#  '내일의',
#  '밝은',
#  '미소로',
#  '이제는',
#  '바꿀',
#  '있어요',
#  '다시',
#  '일어나',
#  '나의',
#  '길을',
#  '향하여',
#  '너만을',
#  '그리워하는만큼',
#  '내게',
#  '다가오진',
#  '않았어',
#  '차가운',
#  '듯한',
#  '미소를',
#  '띠고',
#  '있던',
#  '모습에',
#  '무뚝뚝한',
#  '너의',
#  '말투와',
#  '관심없는',
#  '듯한',
#  '표정이',
#  '닫혀있던',
#  '마음',
#  '나도',
#  '모르게',
#  '이끌렸지',
#  '다음에',
#  '전화한단',
#  '말에',
#  '얼마나',
#  '설레였는지',
#  '몰라',
#  '그런',
#  '마음을',
#  '너는',
#  '알았는지',
#  '시간이',
#  '지난',
#  '다음에',
#  '말을',
#  '할꺼야',
#  '처음만난',
#  '순간',
#  '느낌들을',
#  '위해',
#  '보낸',
#  '날들과',
#  '변해가는',
#  '나의',
#  '얘기까지',
#  '너만을',
#  '좋아한다고',
#  '사랑한다고',
#  '그런',
#  '얘기할',
#  '있는',
#  '날을',
#  '기다려',
#  '바라보는',
#  '눈에',
#  '처음',
#  '느낌',
#  '그대로',
#  '담아',
#  '너에게',
#  '많은걸',
#  '원한만큼',
#  '나에게',
#  '채워지진',
#  '않았어',
#  '표정없이',
#  '먼곳만',
#  '바라',
#  '보았던',
#  '모습에',
#  '지나간',
#  '날의',
#  '다른',
#  '만남이',
#  '있기도',
#  '했었단',
#  '얘기가',
#  '알수',
#  '없는',
#  '너의',
#  '나도',
#  '모르게',
#  '만든거야',
#  '다음에',
#  '전화한단',
#  '말에',
#  '얼마나',
#  '설레였는지',
#  '몰라',
#  '그런',
#  '마음을',
#  '너는',
#  '알았는지',
#  '시간이',
#  '지난',
#  '다음에',
#  '말을',
#  '할꺼야',
#  '처음만난',
#  '순간',
#  '느낌들을',
#  '위해',
#  '보낸',
#  '날들과',
#  '변해가는',
#  '나의',
#  '얘기까지',
#  '너만을',
#  '좋아한다고',
#  '사랑한다고',
#  '그런',
#  '얘기할',
#  '있는',
#  '날을',
#  '기다려',
#  '바라보는',
#  '눈에',
#  '처음',
#  '느낌',
#  '그대로',
#  '담아',
#  '시간이',
#  '지난',
#  '다음에',
#  '말을',
#  '할꺼야',
#  '처음만난',
#  '순간',
#  '느낌들을',
#  '위해',
#  '보낸',
#  '날들과',
#  '변해가는',
#  '나의',
#  '얘기까지',
#  '너만을',
#  '좋아한다고',
#  '사랑한다고',
#  '그런',
#  '얘기할',
#  '있는',
#  '날을',
#  '기다려',
#  '바라보는',
#  '눈에',
#  '처음',
#  '느낌',
#  '그대로',
#  '담아',
#  '언젠가',
#  '당신에게',
#  '주고팠던',
#  '작은',
#  '사랑을',
#  '오늘밤',
#  '당신에게',
#  '나는',
#  '주고',
#  '싶어요',
#  '조금은',
#  '수줍은',
#  '마음에',
#  '머뭇거리기도',
#  '하지만',
#  '달콤한',
#  '초콜렛',
#  '향기가',
#  '너무도',
#  '짙어',
#  '숨길수',
#  '없는',
#  '작은',
#  '사랑을',
#  '오늘밤',
#  '당신과',
#  '함께라면',
#  '작은',
#  '사랑을',
#  '주고만',
#  '싶어요',
#  '사랑의',
#  '향기로',
#  '가득찬',
#  '작은',
#  '사랑을',
#  '그대여',
#  '받아주오',
#  '조금은',
#  '수줍은',
#  '마음에',
#  '머뭇거리기도',
#  '하지만',
#  '달콤한',
#  '초콜렛',
#  '향기가',
#  '너무도',
#  '짙어',
#  '숨길수',
#  '없는',
#  '작은',
#  '사랑을',
#  '오늘밤',
#  '당신과',
#  '함께라면',
#  '작은',
#  '사랑을',
#  '주고만',
#  '싶어요',
#  '사랑의',
#  '향기로',
#  '가득찬',
#  '작은',
#  '사랑을',
#  '그대여',
#  '받아주오',
#  '너를',
#  '미워하지만',
#  '하지만',
#  '그댄',
#  '나를',
#  '떠났잖아',
#  '언제나',
#  '그렇듯',
#  '참고만',
#  '지냈지',
#  '다시는',
#  '만나지',
#  '않는다고',
#  '큰소리',
#  '치겠지만',
#  '또다시',
#  '내게',
#  '올꺼야',
#  '사랑하니까',
#  '하지만',
#  '이제는',
#  '싫어',
#  'STOP',
#  '네게',
#  '사랑은',
#  '이젠',
#  '없어',
#  '너무',
#  '멀리',
#  '가버렸잖니',
#  '차갑게',
#  '토라져',
#  '서있겠지',
#  '바보같은',
#  '너의',
#  '모습은',
#  '이밤이',
#  '지나면',
#  '다시',
#  '전화를',
#  '하겠지',
#  '하지만',
#  '이제는',
#  '너를',
#  '모른다고만',
#  '할꺼야',
#  '생각도',
#  '하기',
#  '싫어',
#  '자꾸만',
#  '눈물이',
#  '흐르니까',
#  '우연히',
#  '만날',
#  '것도',
#  '원하질',
#  '않아',
#  '마음이',
#  '아파와',
#  '네게',
#  '사랑은',
#  '이젠',
#  '없어',
#  '너무',
#  '멀리',
#  '가버렸잖니',
#  '차갑게',
#  '토라져',
#  '서있겠지',
#  '바보같은',
#  '너의',
#  '모습은',
#  '생각도',
#  '하기',
#  '싫어',
#  '자꾸만',
#  '눈물이',
#  '흐르니까',
#  '우연히',
#  '만날',
#  '것도',
#  '원하질',
#  '안아',
#  '마음이',
#  '아파와',
#  '네게',
#  '사랑은',
#  '이젠',
#  '없어',
#  '너무',
#  '멀리',
#  '가버렸잖니',
#  '차갑게',
#  '토라져',
#  '서있겠지',
#  '바보같은',
#  '너의',
#  '모습은',
#  '언젠가는',
#  '우리가',
#  '또다른',
#  '사랑을',
#  '하겠지만',
#  '나는',
#  '너를',
#  '사랑해',
#  '했었어',
#  '하지만',
#  '떠났잖아',
#  '언젠가는',
#  '우리가',
#  '또다른',
#  '사랑을',
#  '하겠지만',
#  '나는',
#  '너를',
#  '사랑해',
#  '했었어',
#  '하지만',
#  '떠났잖아',
#  '언제나',
#  '그렇듯',
#  '차고만',
#  '지냈지',
#  '다시는',
#  '만나지',
#  '않는다고',
#  '큰소리',
#  '치겠지만',
#  '또다시',
#  '내게',
#  '올꺼야',
#  '사랑하니까',
#  '하지만',
#  '이제는',
#  '싫어',
#  'STOP',
#  '샤일라라',
#  '샤일라라',
#  '샤일라라',
#  '샤일라라',
#  '온종일',
#  '너의',
#  '전활',
#  '기다려',
#  '너에게',
#  '건네준',
#  '나의',
#  '번호',
#  '샤일라라',
#  '처음',
#  '너를',
#  '만나던',
#  '그날',
#  '마음',
#  '느낌도',
#  '준거야',
#  '좋은',
#  '노래는',
#  '빨리',
#  '끝나는걸',
#  '너를',
#  '처음보던',
#  '순간의',
#  '설레임',
#  '만이',
#  '나를',
#  '바보로',
#  '만들었던',
#  '거야',
#  '번호만',
#  '기억하지마',
#  '처음',
#  '너의',
#  '오른쪽에',
#  '살며시',
#  '기대었던',
#  '나의',
#  '표정',
#  '미소',
#  '눈빛',
#  '함께',
#  '전화기',
#  '앞에',
#  '앉아서',
#  '너에',
#  '목소리를',
#  '기다리며',
#  '세상에서',
#  '제일',
#  '행복한',
#  '너의',
#  '반쪽',
#  '너의',
#  '바보가',
#  '된거야',
#  '온종일',
#  '너의',
#  '얼굴',
#  '그리며',
#  '수없이',
#  '불러본',
#  '너의',
#  '이름',
#  '샤일라라',
#  '맨처음',
#  '너와',
#  '마주',
#  '앉았때',
#  '마음',
#  '느낌도',
#  '준거야',
#  '좋은',
#  '노랜',
#  '빨리',
#  '끝나는걸',
#  '너를',
#  '처음보던',
#  '순간의',
#  '아쉬움',
#  '나란',
#  '너무',
#  '일찍',
#  '일어섰던',
#  '거야',
#  '번호만',
#  '기억하지마',
#  '맨처음',
#  '너의',
#  '오른쪽에',
#  '살며시',
#  '기대던',
#  '나의',
#  '표정',
#  '미소',
#  '눈빛도',
#  '함께',
#  '전화기',
#  '앞에',
#  '앉아서',
#  '너의',
#  '목소리를',
#  '기다리며',
#  '나는',
#  '세상에서',
#  '제일',
#  '행복한',
#  '너의',
#  '반쪽',
#  '너의',
#  '바보가',
#  '된거야',
#  '번호만',
#  '기억하지마',
#  '맨처음',
#  '너의',
#  '오른쪽에',
#  '살며시',
#  '기대던',
#  '나의',
#  '표정',
#  '미소',
#  '눈빛도',
#  '함께',
#  '전화기',
#  '앞에',
#  '앉아서',
#  '너에',
#  '목소리를',
#  '기다리던',
#  '세상에서',
#  '제일',
#  '행복한',
#  '너의',
#  '반쪽',
#  '너의',
#  '바보가',
#  '된거야',
#  '너의',
#  '바보가',
#  '된거야',
#  '나이제',
#  '끝났어',
#  '너는',
#  '모든게',
#  '변명일',
#  '뿐이야',
#  '그동안',
#  '피하던',
#  '이유가',
#  '떠나갈',
#  '준비였니',
#  '한순간',
#  '좋았던',
#  '기억마저',
#  '망가져',
#  '버렸어',
#  '우연히',
#  '만나도',
#  '우리',
#  '서로를',
#  '모른척',
#  '하길',
#  '바랄뿐야',
#  '누구나',
#  '한번의',
#  '실수쯤은',
#  '있다고',
#  '용서하려고',
#  '노력도',
#  '했어',
#  '하지만',
#  '나와의',
#  '약속을',
#  '잊고',
#  '그녀를',
#  '만나러',
#  '갔던거야',
#  '헤어졌다고',
#  '하던',
#  '그녀를',
#  '언제부터',
#  '속이고',
#  '만나왔는지',
#  '이제는',
#  '용서조차',
#  '가치없어',
#  '이젠',
#  '너를',
#  '깨끗이',
#  '잊을거야',
#  '이젠',
#  '기대하지마',
#  '나도',
#  '너에게',
#  '할만큼',
#  '다했어',
#  '천사표',
#  '순애보란',
#  '그런말이',
#  '어색하지',
#  '않을만큼',
#  '하지만',
#  '이제부터',
#  '새로운',
#  '자유를',
#  '찾겠어',
#  '사랑의',
#  '모든걸',
#  '바쳐',
#  '실패한',
#  '그런',
#  '내모습',
#  '잊어버려',
#  '누구나',
#  '한번의',
#  '실수쯤은',
#  '있다고',
#  '용서하려고',
#  '노력도',
#  '했어',
#  '하지만',
#  '나와의',
#  '약속을',
#  '잊고',
#  '그녀를',
#  '만나러',
#  '갔던거야',
#  '헤어졌다고',
#  '하던',
#  '그녀를',
#  '언제부터',
#  '속이고',
#  '만나왔는지',
#  '이제는',
#  '용서조차',
#  '가치없어',
#  '이젠',
#  '너를',
#  '깨끗이',
#  '잊을거야',
#  '이젠',
#  '믿고',
#  '있었어',
#  '언젠가는',
#  '웃음',
#  '지을',
#  '너란걸',
#  '아직도',
#  '네게',
#  '힘겨운',
#  '이별',
#  '남았다면',
#  '내가',
#  '대신',
#  '간직할게',
#  '하얀눈이',
#  '내려와',
#  '새하얀',
#  '눈이',
#  '내려와',
#  '수줍은',
#  '너의',
#  '모습을',
#  '축복하잖니',
#  '행복해야해',
#  '행복해야해',
#  '너에게',
#  '남은건',
#  '그뿐인걸',
#  '이젠',
#  '눈물',
#  '지우렴',
#  '미운',
#  '얼굴',
#  '되잖니',
#  '새하얀',
#  '드레스에',
#  '모습이',
#  '이렇게',
#  '예쁜데',
#  '고개를',
#  '들어',
#  '주위를',
#  '바라봐',
#  '영원히',
#  '지켜줄',
#  '남자와',
#  '너를',
#  '위해',
#  '기도해',
#  '내가',
#  '있잖아',
#  '언제까지나',
#  '곁엔',
#  '가끔은',
#  '걱정했었어',
#  '야위어가는',
#  '너의',
#  '어깰',
#  '감싸며',
#  '지금도',
#  '네게',
#  '아파할',
#  '기억',
#  '남았다면',
#  '내가',
#  '대신',
#  '지워갈게',
#  '지금까지',
#  '울고있었던',
#  '거야',
#  '외외로움에',
#  '빠져든거야',
#  '이제',
#  '그렇게',
#  '떠나간',
#  '너때문에',
#  '슬픔에',
#  '빠져든거야',
#  '이제너에게',
#  '다른',
#  '사람이',
#  '너너너',
#  '너를지켜보고',
#  '있는건',
#  '하지만',
#  '나는귀가막혀',
#  '있어',
#  '아무데도',
#  '살수가',
#  '없어',
#  '돌아와',
#  '지금',
#  '내곁으로',
#  '내가',
#  '빌고',
#  '있을게',
#  '언제까지나',
#  '기다릴거야',
#  '나의',
#  '약한',
#  '모습이',
#  '너무',
#  '힘들진',
#  '않을까',
#  '그래도',
#  '니가',
#  '필요한걸',
#  '한사람의',
#  '마음을',
#  '나를',
#  '막으려고',
#  '하니',
#  '뒤흔들어',
#  '놓고있는는거야',
#  '니가',
#  '필요해',
#  '니가',
#  '중요해',
#  '여태까지',
#  '애썼던',
#  '나인데',
#  '내손에',
#  '들어올수',
#  '있었잖아',
#  '내꺼였는데',
#  '넌이제',
#  '금방',
#  '잊겠지만',
#  '왜이러잊기가',
#  '힘든걸까',
#  '나만을',
#  '사랑한다고',
#  '하고',
#  '엉엉울게',
#  '만든거',
#  '너였잖아',
#  '그래',
#  '만날',
#  '일이',
#  '없었다면',
#  '이렇게',
#  '괴로워',
#  '하지',
#  '않고',
#  '있을거야',
#  '내게',
#  '이렇게',
#  '시련을',
#  '주고',
#  '있는건지',
#  '나는',
#  '정말',
#  '알수가',
#  '없어',
#  '샤랄라라라라',
#  '샤랄랄라라라라',
#  '괴로워',
#  '괴롭힐땐',
#  '언제고',
#  '또날',
#  '사랑한다는건',
#  '언젠데',
#  '이리',
#  '오락가락',
#  '오락가락',
#  '만드는건',
#  '인지',
#  '모라',
#  '떠날꺼면서',
#  '떠난다면서',
#  '다른사람에게로',
#  '갈거면서',
#  '나의마음만',
#  '나의',
#  '가슴만',
#  '애태우는지',
#  '돌아와',
#  '지금',
#  '내곁으로',
#  '내가',
#  '빌고',
#  '있을게',
#  '언제까지나',
#  '기다릴거야',
#  '나의',
#  '약한',
#  '모습이',
#  '넌이제',
#  '금방',
#  '잊겠지만',
#  '왜이러잊기가',
#  '힘든걸까',
#  '나만을',
#  '사랑한다고',
#  '하고',
#  '엉엉울게',
#  '만든거',
#  '너였잖아',
#  '그래',
#  '만날',
#  '일이',
#  '없었다면',
#  '이렇게',
#  '괴로워',
#  '하지',
#  '않고',
#  '있을거야',
#  '내게',
#  '이렇게',
#  '시련을',
#  '주고',
#  '있는건지',
#  '나는',
#  '정말',
#  '알수가',
#  '없어',
#  '샤랄라라라라',
#  '샤랄랄라라라라',
#  '괴로워',
#  'RAP',
#  '그의',
#  '목소리가',
#  '귓전에',
#  '울렸다',
#  '어떻게',
#  '집으로',
#  '돌아왔는지',
#  '모른다',
#  '그러나',
#  '집에',
#  '돌아오기가',
#  '무섭게',
#  '마지막',
#  '편지를',
#  '썼다',
#  '가슴',
#  '구석구석에',
#  '남아있는',
#  '그의',
#  '기억을',
#  '말끔히',
#  '털어버리려는',
#  '듯이',
#  'SONG',
#  '예정에도',
#  '없던',
#  'summer',
#  'night',
#  '촛불에',
#  '눈물',
#  '감추고',
#  'ah',
#  '그댄',
#  '바람보다',
#  '조용히',
#  '나를',
#  '떠났네',
#  '냉정한',
#  '한마디',
#  '그건',
#  '정말',
#  '진실이',
#  '아니란걸',
#  '네가',
#  '알고',
#  '있으면',
#  '눈으로',
#  '말하던',
#  '모든것이',
#  '되살아나는',
#  '이별의',
#  'oh',
#  'next',
#  'day',
#  '떠오르는건',
#  '붉은',
#  '와인의',
#  'kiss',
#  '너만을',
#  '간직할게',
#  '사랑의',
#  '창을',
#  '그냥',
#  '열어둔',
#  '채로',
#  'RAP',
#  '나른한',
#  '햇살',
#  '이젠',
#  '그대는',
#  ...]

# %%
tokens = tokens.tolist()

# %%
tokens2 = tokens2.tolist()

# %%
# 하나의 리스트로 만들어주기
tokens_all = sum(tokens, [])

# %%
from collections import Counter

Counter(tokens_all).most_common(30)
# Out:
# [('내', 11710),
#  ('I', 10794),
#  ('you', 9499),
#  ('난', 7949),
#  ('me', 6832),
#  ('날', 6690),
#  ('t', 5336),
#  ('oh', 5225),
#  ('Oh', 5075),
#  ('나', 4999),
#  ('더', 4753),
#  ('널', 4735),
#  ('love', 4623),
#  ('나를', 4596),
#  ('it', 4326),
#  ('내가', 4128),
#  ('너', 4095),
#  ('수', 3950),
#  ('넌', 3855),
#  ('그', 3734),
#  ('다', 3494),
#  ('my', 3432),
#  ('너의', 3428),
#  ('baby', 3242),
#  ('이', 3095),
#  ('내게', 3093),
#  ('너를', 3045),
#  ('s', 2870),
#  ('왜', 2753),
#  ('너무', 2742)]

# %%
# 하나의 리스트로 만들어주기
tokens_all2 = sum(tokens2, [])

# %%
from collections import Counter

Counter(tokens_all2).most_common(30)
# Out:
# [('내', 23482),
#  ('I', 21515),
#  ('난', 17453),
#  ('you', 17395),
#  ('널', 13790),
#  ('날', 11729),
#  ('수', 11359),
#  ('t', 10196),
#  ('그', 10149),
#  ('내가', 9559),
#  ('me', 9409),
#  ('너를', 9197),
#  ('나', 8920),
#  ('너의', 8780),
#  ('더', 8493),
#  ('나를', 8093),
#  ('넌', 7902),
#  ('my', 7777),
#  ('다', 7688),
#  ('it', 7418),
#  ('이', 7325),
#  ('love', 7001),
#  ('너', 6820),
#  ('나의', 6775),
#  ('Oh', 6680),
#  ('the', 6663),
#  ('s', 6626),
#  ('oh', 6265),
#  ('없어', 6166),
#  ('걸', 5834)]

# %%
tokens[:3]
# Out:
# [['간직하고픈',
#   '꿈',
#   '있는',
#   '친구여',
#   '푸른',
#   '바다와',
#   '하늘을',
#   '보아요',
#   '때론',
#   '실의와',
#   '고뇌에',
#   '잠들어',
#   '어둔',
#   '빛으로',
#   '살',
#   '순',
#   '없잖아요',
#   '세상은',
#   '오늘만으로',
#   '끝이',
#   '나는건',
#   '아니예요',
#   '이젠',
#   '눈물을',
#   '닦아요',
#   '내일은',
#   '다시',
#   '우리에게',
#   '타오르는',
#   '저',
#   '태양과',
#   '눈',
#   '부신',
#   '기쁜',
#   '날들로',
#   '이제는',
#   '바꿀',
#   '수',
#   '있어요',
#   '어둠은',
#   '걷히고',
#   '나의',
#   '길을',
#   '향하여',
#   '어떤',
#   '때에는',
#   '너무',
#   '힘이',
#   '들어',
#   '누군가',
#   '내게',
#   '있기를',
#   '원했죠',
#   '하지만',
#   '이젠',
#   '언제나',
#   '그렇게',
#   '후회를',
#   '하며',
#   '살',
#   '순',
#   '없잖아요',
#   '세상은',
#   '오늘만으로',
#   '끝이',
#   '나는건',
#   '아니예요',
#   '이젠',
#   '눈물을',
#   '닦아요',
#   '내일은',
#   '다시',
#   '우리에게',
#   '어둠에',
#   '지친',
#   '과거와',
#   '내일의',
#   '밝은',
#   '미소로',
#   '이제는',
#   '바꿀',
#   '수',
#   '있어요',
#   '또',
#   '다시',
#   '일어나',
#   '나의',
#   '길을',
#   '향하여',
#   '내일은',
#   '다시',
#   '우리에게',
#   '타오르는',
#   '저',
#   '태양과',
#   '눈',
#   '부신',
#   '기쁜',
#   '날들로',
#   '이제는',
#   '바꿀',
#   '수',
#   '있어요',
#   '어둠은',
#   '걷히고',
#   '나의',
#   '길을',
#   '향하여',
#   '내일은',
#   '다시',
#   '우리에게',
#   '어둠에',
#   '지친',
#   '과거와',
#   '내일의',
#   '밝은',
#   '미소로',
#   '이제는',
#   '바꿀',
#   '수',
#   '있어요',
#   '또',
#   '다시',
#   '일어나',
#   '나의',
#   '길을',
#   '향하여'],
#  ['너만을',
#   '그리워하는만큼',
#   '넌',
#   '내게',
#   '다가오진',
#   '않았어',
#   '차가운',
#   '듯한',
#   '미소를',
#   '띠고',
#   '있던',
#   '네',
#   '모습에',
#   '무뚝뚝한',
#   '너의',
#   '그',
#   '말투와',
#   '관심없는',
#   '듯한',
#   '그',
#   '표정이',
#   '닫혀있던',
#   '내',
#   '마음',
#   '나도',
#   '모르게',
#   '이끌렸지',
#   '다음에',
#   '전화한단',
#   '그',
#   '말에',
#   '얼마나',
#   '설레였는지',
#   '몰라',
#   '그런',
#   '내',
#   '마음을',
#   '너는',
#   '알았는지',
#   '시간이',
#   '지난',
#   '다음에',
#   '난',
#   '말을',
#   '할꺼야',
#   '널',
#   '처음만난',
#   '순간',
#   '그',
#   '느낌들을',
#   '널',
#   '위해',
#   '보낸',
#   '날들과',
#   '변해가는',
#   '나의',
#   '얘기까지',
#   '너만을',
#   '좋아한다고',
#   '날',
#   '사랑한다고',
#   '그런',
#   '얘기할',
#   '수',
#   '있는',
#   '날을',
#   '기다려',
#   '날',
#   '바라보는',
#   '네',
#   '눈에',
#   '처음',
#   '느낌',
#   '그대로',
#   '담아',
#   '너에게',
#   '많은걸',
#   '원한만큼',
#   '나에게',
#   '채워지진',
#   '않았어',
#   '표정없이',
#   '먼곳만',
#   '바라',
#   '보았던',
#   '네',
#   '모습에',
#   '지나간',
#   '날의',
#   '다른',
#   '만남이',
#   '있기도',
#   '했었단',
#   '그',
#   '얘기가',
#   '알수',
#   '없는',
#   '너의',
#   '맘',
#   '나도',
#   '모르게',
#   '만든거야',
#   '다음에',
#   '전화한단',
#   '그',
#   '말에',
#   '얼마나',
#   '설레였는지',
#   '몰라',
#   '그런',
#   '내',
#   '마음을',
#   '너는',
#   '알았는지',
#   '시간이',
#   '지난',
#   '다음에',
#   '난',
#   '말을',
#   '할꺼야',
#   '널',
#   '처음만난',
#   '순간',
#   '그',
#   '느낌들을',
#   '널',
#   '위해',
#   '보낸',
#   '날들과',
#   '변해가는',
#   '나의',
#   '얘기까지',
#   '너만을',
#   '좋아한다고',
#   '날',
#   '사랑한다고',
#   '그런',
#   '얘기할',
#   '수',
#   '있는',
#   '날을',
#   '기다려',
#   '날',
#   '바라보는',
#   '네',
#   '눈에',
#   '처음',
#   '느낌',
#   '그대로',
#   '담아',
#   '시간이',
#   '지난',
#   '다음에',
#   '난',
#   '말을',
#   '할꺼야',
#   '널',
#   '처음만난',
#   '순간',
#   '그',
#   '느낌들을',
#   '널',
#   '위해',
#   '보낸',
#   '날들과',
#   '변해가는',
#   '나의',
#   '얘기까지',
#   '너만을',
#   '좋아한다고',
#   '날',
#   '사랑한다고',
#   '그런',
#   '얘기할',
#   '수',
#   '있는',
#   '날을',
#   '기다려',
#   '날',
#   '바라보는',
#   '네',
#   '눈에',
#   '처음',
#   '느낌',
#   '그대로',
#   '담아'],
#  ['언젠가',
#   '당신에게',
#   '주고팠던',
#   '내',
#   '작은',
#   '사랑을',
#   '오늘밤',
#   '당신에게',
#   '나는',
#   '꼭',
#   '주고',
#   '싶어요',
#   '조금은',
#   '수줍은',
#   '마음에',
#   '머뭇거리기도',
#   '하지만',
#   '달콤한',
#   '초콜렛',
#   '향기가',
#   '너무도',
#   '짙어',
#   '숨길수',
#   '없는',
#   '이',
#   '작은',
#   '사랑을',
#   '오늘밤',
#   '당신과',
#   '함께라면',
#   '내',
#   '작은',
#   '사랑을',
#   '주고만',
#   '싶어요',
#   '사랑의',
#   '향기로',
#   '가득찬',
#   '밤',
#   '내',
#   '작은',
#   '사랑을',
#   '그대여',
#   '받아주오',
#   '조금은',
#   '수줍은',
#   '마음에',
#   '머뭇거리기도',
#   '하지만',
#   '달콤한',
#   '초콜렛',
#   '향기가',
#   '너무도',
#   '짙어',
#   '숨길수',
#   '없는',
#   '이',
#   '작은',
#   '사랑을',
#   '오늘밤',
#   '당신과',
#   '함께라면',
#   '내',
#   '작은',
#   '사랑을',
#   '주고만',
#   '싶어요',
#   '사랑의',
#   '향기로',
#   '가득찬',
#   '밤',
#   '내',
#   '작은',
#   '사랑을',
#   '그대여',
#   '받아주오']]

# %%
tokens_all[:3]
# Out:
# ['간직하고픈', '꿈', '있는']

# %%
tokens_all[1]
# Out:
# '꿈'

# %%
search_word = "여자"
tokens_all.index(search_word)
# Out:
# 5166

# %%
search_word = "여자"
tokens_all2.index(search_word)
# Out:
# 63949

# %%
next_word = tokens_all2[tokens_all2.index(search_word):tokens_all2.index(search_word) + 5]
next_word
# Out:
# ['여자', '없다고', 'Lovin', 'u', '널']

# %%
indices = [i for i, x in enumerate(tokens_all) if x == search_word]
indices[:10]
# Out:
# [5166, 7959, 17289, 34400, 48428, 48524, 55669, 55732, 55765, 55831]

# %%
indices2 = [i for i, x in enumerate(tokens_all2) if x == search_word]
indices2[:10]
# Out:
# [63949, 71567, 71943, 76684, 76884, 78233, 80736, 97001, 97062, 127290]

# %%
indices[0]
# Out:
# 5166

# %%
# 가사에 search_word가 몇 번 나오는지 보기
len(indices)
# Out:
# 253

# %%
# 가사에 search_word가 몇 번 나오는지 보기
len(indices2)
# Out:
# 411

# %%
# tokens_all[tokens_all.index(search_word)]

# %%
# property_asel = [property_a[i] for i in good_indices]

# %%
tokens_all[indices[i]:indices[i] + 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-346acc34025a> in <module>()
# ----> 1 tokens_all[indices[i]:indices[i] + 5]
#
# TypeError: list indices must be integers or slices, not list

# %%
# indices의 값들이 index인 모든 search_word의 next_word를 구하고 싶다.
i = 0
result = []
for i in range(len(indices)):
    next_word_1 = tokens_all[indices[i]:indices[i] + 5]
    result.append(next_word_1)
    i+=1
    continue

# %%
result
# Out:
# [['여자', '한번', '깊이깊이', '찾아봐', '나처럼'],
#  ['여자', '한번', '깊이깊이', '찾아봐', '나처럼'],
#  ['여자', '이름을', '부르지', '난', '이해못해'],
#  ['여자', '맘을', '너무', '몰라줘', '까만'],
#  ['여자', '되고', '싶은맘이', '간절해져요', '혹시'],
#  ['여자', '되고', '싶은맘이', '간절해져요', '혹시'],
#  ['여자', '해봐', 'oh', '해봐', 'oh'],
#  ['여자', '해봐', 'oh', '해봐', 'oh'],
#  ['여자', '없어요', '아가씨', '정말', '예뻐요'],
#  ['여자', '해봐', 'oh', '해봐', 'oh'],
#  ['여자', '해봐', 'oh', '해봐', 'oh'],
#  ['여자', '될거라는', '그런', '기대도', '하지마'],
#  ['여자', '될거라는', '그런', '기대도', '하지마'],
#  ['여자', '원했잖아', '날', '떠나', '세상'],
#  ['여자', '만나', '내게', '해준', '만큼'],
#  ['여자', '만나', '내게', '해준', '만큼'],
#  ['여자', '만난', '걸', '내버려둘까', '그렇게는'],
#  ['여자', '없을걸', '오락가락', '고민해봐야', '나만한'],
#  ['여자', '없을걸', '오락가락', '고민', '해봐야'],
#  ['여자', '차라리', '모두다', '잊자', '그래'],
#  ['여자', '웃자웃자', '웃어버리자', '오늘은', '금요일밤이잖아'],
#  ['여자', '꽤', '많겠는걸', '스트레스', '좀'],
#  ['여자', '손에', '걸친', '백을', '들고'],
#  ['여자', '너와', '어울리지', '않아', '걔는'],
#  ['여자', '누구와도', '비교할', '수', '없는'],
#  ['여자', '난', '그런', '여자', '빛나는'],
#  ['여자', '빛나는', '여자', 'Baby', 'J'],
#  ['여자', 'Baby', 'J', 'Baby', 'J'],
#  ['여자', '만들어', '버렸어', '부드러운', '니'],
#  ['여자', '친군', '아니잖아', '어쩌면', '난'],
#  ['여자', '옆에만', '있어주길', '원하는', '바램들이'],
#  ['여자', '그리', '울리다', '큰', '코'],
#  ['여자', '남자', '된', '널', '오늘도'],
#  ['여자', '여럿', '울렸댔지', '양다린', '기본이었고'],
#  ['여자', '대하면서', '내쪽을', '살피는', '너'],
#  ['여자', '누구보다', '매력이', '터지는걸', 'It'],
#  ['여자', '누구보다', '매력이', '터지는걸', 'It'],
#  ['여자', '누구보다', '매력이', '터지는걸', 'It'],
#  ['여자', '매력', '없다', '해도', '아쉬운'],
#  ['여자', '랩퍼', '솔직히', '싱겁네', '착한'],
#  ['여자', '내', '코까지', '역겨운', 'Perfume'],
#  ['여자', '못', '만날', '거다', '영원히'],
#  ['여자', '못', '만날거다', '영원히', '넌넌넌'],
#  ['여자', '못', '만날거다', '영원히', '넌'],
#  ['여자', '친구가', '되고', '싶었거든', '착각에'],
#  ['여자', '내', '코까지', '역겨운', 'Perfume'],
#  ['여자', '외계인처럼', '지구를', '탓하지만', 'boys'],
#  ['여자', '외계인처럼', '지구를', '탓하지만', 'boys'],
#  ['여자', '외계인처럼', '지구를', '탓하지만', 'boys'],
#  ['여자', '외계인처럼', '지구를', '탓하지만', 'boys'],
#  ['여자', '외계인처럼', '지구를', '탓하지만', 'boys'],
#  ['여자', '외계인처럼', '지구를', '탓하지만', 'boys'],
#  ['여자', '친구', '나라면', '자꾸', '어리광'],
#  ['여자', '친구', '나라면', 'I', 'm'],
#  ['여자', '친구라면', '내', '남자친구라면', '그'],
#  ['여자', '안에서', '사랑', '안에서', '행복하지'],
#  ['여자', '웃음소리가', '들려', 'oh', 'no'],
#  ['여자', '허리에', '너의', '손을', '올려'],
#  ['여자', '맘', '훔치지마', 'You', 're'],
#  ['여자', '맘', '훔치지마', 'You', 're'],
#  ['여자', '지나가는데도', '나한테', '시선고정', '스킨쉽하고'],
#  ['여자', '아니예요', '이름이', '뭐예요', 'What'],
#  ['여자', '아니예요', '이름이', '뭐예요', 'What'],
#  ['여자', '만나야', '돼', '나보다', '더'],
#  ['여자', '잠깐이면', '돼', '금방', '잊혀질'],
#  ['여자', '만나야', '돼', '나보다', '더'],
#  ['여자', '잠깐이면', '돼', '금방', '잊혀질'],
#  ['여자', '아니예요', '이름이', '뭐예요', 'What'],
#  ['여자', '아니예요', '이름이', '뭐예요', 'What'],
#  ['여자', '놓치는', '건', '너잖아', '너잖아'],
#  ['여자', '놓치는', '건', '너잖아', '너잖아'],
#  ['여자', '만나고', '착한', '척', '해'],
#  ['여자', '맘을', '몰라도', '넌', '너무'],
#  ['여자', '맘을', '몰라도', '넌', '너무'],
#  ['여자', '놓치지는', '말아줘', 'why', 'can'],
#  ['여자', '만나도', '바람을', '피워도', '다'],
#  ['여자', '다리가', '예쁜', '여자', '그게'],
#  ['여자', '그게', '바로', '나야', '아직'],
#  ['여자', '동생이라고', '급', '당황한', '모습'],
#  ['여자', '아니야', '나쁜', '여자', '아니에요'],
#  ['여자', '아니에요', '내', '맘', '알아주세요'],
#  ['여자', '이제는', '널', '지울게', '지칠'],
#  ['여자', '아니', '미련하게', '애태우고만', '있지'],
#  ['여자', '애들', '중에', '한사람인', '것'],
#  ['여자', '처음', '봐', 'Behold', '그래'],
#  ['여자', '어디도', '없어', '그냥', '말해줘'],
#  ['여자', '친구로서는', '내가', '좀', '별로니'],
#  ['여자', '친구로서는', '내가', '좀', '별로니'],
#  ['여자', '돼', '언제나', '미안해', '매력'],
#  ['여자', '만난다는', '되도', '않는', '거짓말들'],
#  ['여자', '만난다는', '되도', '않는', '거짓말들'],
#  ['여자', '되어줄게', '사랑에', '빠지면', '난'],
#  ['여자', '되어줄게', '사랑에', '빠지면', '난'],
#  ['여자', '되어줄게', '사랑에', '빠지면', '난'],
#  ['여자', '꿈같은', '우리', '눈앞에', '꺼내줄게'],
#  ['여자', '맘을', '몰라', '넌', '몰라'],
#  ['여자', '꿈같은', '우리', '눈앞에', '꺼내줄게'],
#  ['여자', '맘을', '몰라', '넌', '몰라'],
#  ['여자', '맘을', '몰라', '넌', '몰라'],
#  ['여자', '봤어', 'Good', 'man', '망설일'],
#  ['여자', '밀당의', '고수', '였나', '난'],
#  ['여자', '난', '다룰', '줄', '아는'],
#  ['여자', '제대로', '날', '모른다면', '함부로'],
#  ['여자', '먼저', '이런', '말하고', '오'],
#  ['여자', '우린', '정말', '어울려', '니가'],
#  ['여자', '감당하긴', '쉽지않아', '애가타게', '더는'],
#  ['여자', '감당하긴', '쉽지않아', '애가타게', '더는'],
#  ['여자', '감당하긴', '쉽지않아', '애가타게', '더는'],
#  ['여자', '마음', '다', '소박해서', '사랑해'],
#  ['여자', '맘', '똑같애서', '잠깐', '사이로'],
#  ['여자', '마음', '다', '소박해서', '사랑해'],
#  ['여자', '마음', '다', '소박해서', '사랑해'],
#  ['여자', '오빠', '선배', '하다가도', '가끔은'],
#  ['여자', '남자가', '원하는', '게', '뭔지'],
#  ['여자', '마냥', '아이', '같다가도', '남자를'],
#  ['여자', '날', '사랑하게', '만들거야', '드디어'],
#  ['여자', '난', '그렇게', '살', '거야'],
#  ['여자', '맘은', '갈대', '같다더니', '내'],
#  ['여자', '맘은', '갈대', '같다더니', '내'],
#  ['여자', '향기', '옆자리에', '태웠던', '앤'],
#  ['여자', '향기', '옆', '자리에', '태웠던'],
#  ['여자', '맘을', '몰라', '너무', '몰라'],
#  ['여자', '마음을', '널', '보면', '난'],
#  ['여자', '보면', '큰', '소리로', '화낼거야'],
#  ['여자', '두근', '두근', '두근', '떨려와'],
#  ['여자', '인가요', '하루에도', '열두', '번씩'],
#  ['여자', '난', 'B', '형', '여자'],
#  ['여자', '어디로', '튈지', '몰라', '요'],
#  ['여자', '난', 'B', '형', '여자'],
#  ['여자', '내', '맘을', '가져봐요', '어'],
#  ['여자', '난', 'B', '형', '여자'],
#  ['여자', '어디로', '튈지', '몰라요', '어'],
#  ['여자', '난', 'B', '형', '여자'],
#  ['여자', '내', '맘을', '가져봐요', '어'],
#  ['여자', '난', 'B', '형', '여자'],
#  ['여자', '어디로', '튈지', '몰라요', '어'],
#  ['여자', '난', 'B', '형', '여자'],
#  ['여자', '내', '맘을', '가져봐요', '어'],
#  ['여자', '나도', '몰래', '다른', '남자'],
#  ['여자', '뒤에', '숨어', '떠나달래', '날'],
#  ['여자', '친구래', '모든게', '다', '마음에'],
#  ['여자', '애들하고', '나', '보란', '듯이'],
#  ['여자', '동생들', '많네', 'GO', 'AWAY'],
#  ['여자', '친군', '있을까', '수줍은', '척'],
#  ['여자', '친군', '있을까', '수줍은', '척'],
#  ['여자', 'You', 'don', 't', 'love'],
#  ['여자', '맘을', '몰라', 'You', 'don'],
#  ['여자', 'You', 'don', 't', 'love'],
#  ['여자', '맘을', '몰라', 'You', 'don'],
#  ['여자', 'You', 'don', 't', 'love'],
#  ['여자', '나는', '아냐', 'Love', 'is'],
#  ['여자', '나는', '아냐', 'Love', 'is'],
#  ['여자', '맘은', '내가', '아는데', '내가'],
#  ['여자', '맘은', '내가', '아는데', '내가'],
#  ['여자', '맘은', '내가', '아는데', '내가'],
#  ['여자', '대신', '다른걸', '원하는', '거니'],
#  ['여자', '만나봐', '너랑', '똑같은', '사람'],
#  ['여자', '만나서', '너랑', '똑같은', '사랑해'],
#  ['여자', '만나봐', '너랑', '똑같은', '사람'],
#  ['여자', '만나서', '너랑', '똑같은', '사랑해'],
#  ['여자', '만나봐', '똑같은', '사랑해', '봐'],
#  ['여자', '만나봐', '너랑', '똑같은', '사람'],
#  ['여자', '만나서', '너랑', '똑같은', '사랑해'],
#  ['여자', '난', '상관없어', '열정이', 'Key'],
#  ['여자', '난', '상관없어', '열정이', 'Key'],
#  ['여자', '답지', '않지만', '니', '앞에선'],
#  ['여자', '그만', '봐', '내', '남자로'],
#  ['여자', '보면', '죽어', '나를', '만날'],
#  ['여자', '얘기', '힘들어', '숨막혀', '너'],
#  ['여자', '보면', '죽어', '나를', '만날'],
#  ['여자', '얘기', '힘들어', '숨막혀', '너'],
#  ['여자', '두면', '죽어', '다른', '여자'],
#  ['여자', '두고', '날', '만나도', '죽어'],
#  ['여자', '볼', '줄', '모르면', '가던'],
#  ['여자', '볼줄', '모르면', '가던', '길'],
#  ['여자', '너', '기분', '나쁜', '남자'],
#  ['여자', '너', '기분', '나쁜', '남자'],
#  ['여자', '너', '기분', '나쁜', '남자'],
#  ['여자', '찾아', '보던가', '아니면', '가던'],
#  ['여자', '찾아', '보던가', '아니면', '가던'],
#  ['여자', '찾아', '보던가', '아니면', '가던'],
#  ['여자', '마음을', '조금만', '이해해주는', '그런'],
#  ['여자', '마음을', '조금만', '이해해주는', '그런'],
#  ['여자', '마음을', '조금만', '이해해주는', '그런'],
#  ['여자', '마음을', '조금만', '이해해주는', '그런'],
#  ['여자', '맘을', '조금만', '이해해주는', '그런'],
#  ['여자', '맘을', '조금만', '이해해주는', '그런'],
#  ['여자', '땜에', '우는', '나를', '아냐고'],
#  ['여자', '땜에', '우는', '나를', '아냐고'],
#  ['여자', '대통령', '이세상이', '바뀐걸', '인정'],
#  ['여자', '대통령', '이세상이', '바뀐걸', '인정'],
#  ['여자', '할래', '다른', '남자의', '옆에서'],
#  ['여자', '할래', '기대해', '기대해', '음'],
#  ['여자', '할래', '다른', '남자의', '옆에서'],
#  ['여자', '할래', '기대해', '기대해', '생각하면'],
#  ['여자', '할래', '다른', '남자의', '옆에서'],
#  ['여자', '할래', '기대해', '기대해', '음'],
#  ['여자', '맘을', '몰라', '우', '다른'],
#  ['여자', '맘을', '몰라', '우', '다른'],
#  ['여자', '맘을', '몰라요', '뭘', '원하는지'],
#  ['여자', '맘을', '몰라', '우', '다른'],
#  ['여자', '맘을', '몰라', '우', '다른'],
#  ['여자', '같은', '한', '사람', '바로'],
#  ['여자', '번호만', '수십', '개', '딱'],
#  ['여자', '말하자면', '느낌', '있는', '여자'],
#  ['여자', '자신', '있으면', '나를', '따라'],
#  ['여자', '말하자면', '느낌', '있는', '여자'],
#  ['여자', '자신', '있으면', '나를', '따라'],
#  ['여자', '말하자면', '느낌', '있는', '여자'],
#  ['여자', '자신', '있으면', '나를', '따라'],
#  ['여자', '말하자면', '느낌', '있는', '여자'],
#  ['여자', '자신', '있으면', '나를', '따라'],
#  ['여자', '누구예요', '여자였어', 'OH', 'MY'],
#  ['여자', '있는', '것', '같다고', 'awwww'],
#  ['여자', '하지', '말라면', '더하는', '일곱'],
#  ['여자', '품', '안에', '사랑', '받고'],
#  ['여자', '한마디로', '괴짜', '날', '못'],
#  ['여자', '나', '같은', '남자', '너'],
#  ['여자', '톡', '쏘니', '확', '튀니'],
#  ['여자', '너', '같은', '남자', '나'],
#  ['여자', '너', '같은', '남자', '이런'],
#  ['여자', '너', '같은', '남자', '나'],
#  ['여자', '너', '같은', '남자', '나'],
#  ['여자', '너', '같은', '남자', '나'],
#  ['여자', '너', '같은', '남자', '나의'],
#  ['여자', '너', '같은', '남자', 'I'],
#  ['여자', '품', '안에', '사랑', '받고'],
#  ['여자', '없다', '한', '번', '생각해'],
#  ['여자', '지나갈', '때', '넌', '그래도'],
#  ['여자', '밀듯', '밀듯', '당기고만', '있는'],
#  ['여자', '반짝반짝한', '나의', '예쁜', '여자가'],
#  ['여자', '아직은', '우리', '어색한', '사이인걸'],
#  ['여자', '소문은', '요', '참', '어이가'],
#  ['여자', '소문은', '요', '참', '어이가'],
#  ['여자', '하곤', '달라', '네', '눈빛만'],
#  ['여자', '때문에', '또', '예민했어', '상관없어'],
#  ['여자', 'yeah', '날', '원한다면', '지금'],
#  ['여자', '맘', '그렇게', '몰라', '너는'],
#  ['여자', '그게', '나인걸', 'Let', 'me'],
#  ['여자', '맘', '꿰뚫어보는', '널', 'Sweet'],
#  ['여자', '맘', '꿰뚫어보는', '널', 'Sweet'],
#  ['여자', '하트', '눌렀네', 'Hey', 'los'],
#  ['여자', '생긴', '거라면', '혼자', '있고'],
#  ['여자', '생긴', '거라면', '혼자', '있고'],
#  ['여자', '보기를', '돌', '같이', '본다고'],
#  ['여자', '그만', '관리하고', '싹', '다'],
#  ['여자', '있나', '한번', '찾아봐', '왜'],
#  ['여자', '함께', '무심하게', '스치면서', '웃어넘긴거야'],
#  ['여자', '품에서', '또', '또', '거짓'],
#  ['여자', '생긴', '거야', '하늘에', '벌'],
#  ['여자', '불러', '왜', '더는', '빼지'],
#  ['여자', '왜', '친구들도', '다', '아는데'],
#  ['여자', '생겼니', '너', '그러다', '후회해']]

# %%
# 하나의 리스트로 만들어주기
result_one = sum(result, [])

# %%
i = 0
result2 = []
for i in range(len(indices2)):
    next_word_2 = tokens_all2[indices2[i]:indices2[i] + 5]
    result2.append(next_word_2)
    i+=1
    continue

# %%
# i = 0
# result2 = []
# for i in range(len(indices)):
#     next_word_1 = tokens_all2[indices[i] - 5:indices[i] + 5]
#     result2.append(next_word_1)
#     i+=1
#     continue

# %%
result2
# Out:
# [['여자', '없다고', 'Lovin', 'u', '널'],
#  ['여자', '앞에', '이런', '내모습', '본적'],
#  ['여자', '내게', '도와', '달라고', '울며'],
#  ['여자', '하나', '때문에', '깨버릴수는', '없는거잖아'],
#  ['여자', '앞에', '이런', '내모습', '본적'],
#  ['여자', '생겼다는게', '이렇게', '헤어', '나올'],
#  ['여자', '내게', '도와', '달라고', '울며'],
#  ['여자', '믿을수도', '없는', '우리만의', '썸씽'],
#  ['여자', '얼마든지', '옆에', '둘수', '있는'],
#  ['여자', '잘생긴', '남자', '팔짱', '끼고'],
#  ['여자', '서로의', '개성을', '살리자', '신세대여'],
#  ['여자', '여자', '여자는', '감정이', '풍부한'],
#  ['여자', '여자는', '감정이', '풍부한', '사람이지'],
#  ['여자', '대책', '안', '서', '부모님은'],
#  ['여자', '왜', '나를', '모른척', '할까'],
#  ['여자', '언짢은', '기분에', '나가려', '할때'],
#  ['여자', '애인은', '아닐까', '바로', '그'],
#  ['여자', '입을', '다물지', '못해', '너무'],
#  ['여자', '옆을', '지나서', '그냥', '사라져갔어'],
#  ['여자', '내', '친구', '애인이야', '바로'],
#  ['여자', '입을', '다물지못해', '너무', '미안해서'],
#  ['여자', '친구가', '만나자고', '하면', '핑계만'],
#  ['여자', '누구야라는', '말소리에', '놀라', '정신차리고'],
#  ['여자', '처음이야', '나', '정말', '힘들었어'],
#  ['여자', '혹은', '내가', '반한', '여자'],
#  ['여자', '있어도', '아무말', '못하고', '바보처럼'],
#  ['여자', '내', '터프함에', '모두', '다'],
#  ['여자', '저', '여자', '모두다', '내'],
#  ['여자', '모두다', '내', '여자이길', '바래'],
#  ['여자', '저', '여자', '모두다', '내'],
#  ['여자', '모두다', '내', '여자이길', '바래'],
#  ['여자', '혹은', '내가', '반한', '여자'],
#  ['여자', '있어도', '아무말', '못하고', '바보처럼'],
#  ['여자', '내', '터프함에', '모두', '다'],
#  ['여자', '저', '여자', '모두다', '내'],
#  ['여자', '모두다', '내', '여자이길', '바래'],
#  ['여자', '저', '여자', '모두다', '내'],
#  ['여자', '모두다', '내', '여자이길', '바래'],
#  ['여자', '같던', '니가', '그', '동안'],
#  ['여자', '너도', '이제', '사랑을', '아네'],
#  ['여자', '친구들', '너', '하나', '믿고'],
#  ['여자', '친구들', '너', '하나', '믿고'],
#  ['여자', '처음이야', '나', '정말', '힘들었어'],
#  ['여자', '일', '년을', '못', '넘겼지'],
#  ['여자', '늠름한', '남자', '원한다면', '진짜'],
#  ['여자', '보이잖아', '그깟', '자존심', '버릴땐'],
#  ['여자', '어디없나', '매일', '이렇게', '꿈꾸는'],
#  ['여자', '주인공', '번진', '마스카라는', '지우고'],
#  ['여자', '많은데', '양심의', '가책', '때문에'],
#  ['여자', '중에', '왜', '하필이면', '너냐고'],
#  ['여자', '함께해도', '가슴이', '자꾸', '허전해'],
#  ['여자', '내', '앞에선', '통하지', '않았어'],
#  ['여자', '중에', '정말', '못생긴', '여자라곤'],
#  ['여자', '모두다', '정말', '눈부시게', '예뻤지만'],
#  ['여자', '왜', '모두다', '예쁜거야', '왜'],
#  ['여자', '데려가줘', '나를', '떠난', '여자들이'],
#  ['여자', '왜', '모두', '다', '이쁜거야'],
#  ['여자', '만나나', '항상', '감시한대', '어쩌다'],
#  ['여자', '만나나', '항상', '감시한대', '어쩌다'],
#  ['여자', '많은데', '양심의', '가책', '때문에'],
#  ['여자', '세상', '가장', '폼', '나는'],
#  ['여자', '터져', '버릴', '것만', '같은'],
#  ['여자', '없니', '나중에', '딴소리마', '다'],
#  ['여자', '낯익은', '그', '얼굴', '집에'],
#  ['여자', 'for', 'life', '수많은', '사람들'],
#  ['여자', '화를', '내봐도', '니가', '소릴'],
#  ['여자', '어젠', '니', '얘길', '한'],
#  ['여자', '화를', '내봐도', '니가', '소릴'],
#  ['여자', 'You', 're', 'bad', 'bad'],
#  ['여자', '화를', '내봐도', '니가', '소릴'],
#  ['여자', '좋은', '냄새도', '그녀의', '두'],
#  ['여자', '못들은', '척', '해도', '두'],
#  ['여자', 'You', 're', 'bad', 'bad'],
#  ['여자', '화를', '내봐도', '니가', '소릴'],
#  ['여자', '어젠', '니', '얘길', '한'],
#  ['여자', '화를', '내봐도', '니가', '소릴'],
#  ['여자', 'You', 're', 'bad', 'bad'],
#  ['여자', '화를', '내봐도', '니가', '소릴'],
#  ['여자', '좋은', '냄새도', '그녀의', '두'],
#  ['여자', '못들은', '척', '해도', '두'],
#  ['여자', 'You', 're', 'bad', 'bad'],
#  ['여자', '난', '그대로인', '걸요', '너무'],
#  ['여자', '난', '그대로인', '걸요', '너무'],
#  ['여자', '난', '그대로인', '걸요', '너무'],
#  ['여자', '난', '그대로인', '걸요', '너무'],
#  ['여자', '난', '그대로인', '걸요', '너무'],
#  ['여자', '난', '그대로인', '걸요', '너무'],
#  ['여자', '내가', '말했던', '즐거웠던', '시간'],
#  ['여자', '만날', '수', '있을', '것'],
#  ['여자', '만날', '수', '있을', '것같아'],
#  ['여자', '앞에', '서면', '다르지', '사랑은'],
#  ['여자', '앞에', '서면', '다르지', '사랑은'],
#  ['여자', '앞에', '서면', '다르지', '사랑은'],
#  ['여자', '앞에', '서면', '다르지', '사랑은'],
#  ['여자', '앞에', '서면', '다르지', '사랑은'],
#  ['여자', '앞에', '서면', '다르지', '사랑은'],
#  ['여자', '때문에', '고생하네', '참', '딱해'],
#  ['여자', '지나치게', '한', '걸', '너만을'],
#  ['여자', '별로', '큰', '의미가', '없는걸'],
#  ['여자', '별로', '큰', '의미가', '없는걸'],
#  ['여자', '별로', '큰', '의미가', '없는걸'],
#  ['여자', '였다고', '바보같이', '내가', '너에게'],
#  ['여자', '도대체', '어떤', '여잔지', '넌'],
#  ['여자', '너무나', '많은', '남자', '울렸던'],
#  ['여자', '너의', '마음을', '모두', '다'],
#  ['여자', '였다고', '바보같이', '내가', '너에게'],
#  ['여자', '별로', '큰', '의미가', '없는걸'],
#  ['여자', '만나길', '지금껏', '기다려온', '보람이'],
#  ['여자', '만나길', '지금껏', '기다려온', '보람이'],
#  ['여자', '니가', '책속에서', '정말', '찾아봐봐'],
#  ['여자', '바로', '너라는', '걸', '이것저것'],
#  ['여자', '또만날', '이유가', '없어', '세상'],
#  ['여자', '만나도', '결코', '널', '잊는건'],
#  ['여자', '만나도', '결코', '널', '잊는건'],
#  ['여자', '아니잖아', '하지만', '내가', '싫어'],
#  ['여자', '없어', '난', '그래', '그'],
#  ['여자', '기다리며', '살아왔거든', '너라면은', '뭐든지'],
#  ['여자', '지나가도', '나는', '그저', '너'],
#  ['여자', '사인', '친구가', '될', '수'],
#  ['여자', '못', '말리는', '여자', '괜찮은'],
#  ['여자', '괜찮은', '여자', '나를', '위해주는'],
#  ['여자', '나를', '위해주는', '여자', '애교'],
#  ['여자', '애교', '많은', '여자', '꿈이'],
#  ['여자', '꿈이', '너무', '많은', '여자'],
#  ['여자', '순수한', '여자', '내가', '원하는'],
#  ['여자', '내가', '원하는', '여자', '완벽한'],
#  ['여자', '완벽한', '여자', '손이', '예쁜'],
#  ['여자', '손이', '예쁜', '여자', '옷'],
#  ['여자', '옷', '잘', '입는', '여자'],
#  ['여자', '감각', '있는', '여자', '인격'],
#  ['여자', '인격', '있는', '여자', '나를'],
#  ['여자', '나를', '나만을', '영원히', '사랑해'],
#  ['여자', '이런', '여자는', '세상엔', '없다'],
#  ['여자', '근데', '아닌데', '뭔가', '다른데'],
#  ['여자', '근데', '아닌데', '뭔가', '다른데'],
#  ['여자', '킬러', '문자', '썼다', '지웠다가'],
#  ['여자', '일색이란', '생각들은', '보편적', '도도하게'],
#  ['여자', '얼굴은', '안', '봐', '내가'],
#  ['여자', '화목토', '쟤가', '내', '여자'],
#  ['여자', '오빠', '나도', '데려가', '일요일'],
#  ['여자', '킬러', '문자', '썼다', '지웠다가'],
#  ['여자', '일색이란', '생각들은', '보편적', '도도하게'],
#  ['여자', '일색이란', '생각들은', '보편적', '도도하게'],
#  ['여자', '일색이란', '생각들은', '보편적', '도도하게'],
#  ['여자', '만날', '때가', '아닌', '듯'],
#  ['여자', '얼굴은', '안', '봐', '내가'],
#  ['여자', '화목토', '쟤가', '내', '여자'],
#  ['여자', '오빠', '나도', '데려가', '일요일'],
#  ['여자', '일색이란', '생각들은', '보편적', '도도하게'],
#  ['여자', '다시', '만날', '순', '없지만'],
#  ['여자', '찾느니', '차라리', '나', '그냥'],
#  ['여자', '몰라', 'I', 'm', 'your'],
#  ['여자', '보고', '살짝', '곁눈질도', '해보고'],
#  ['여자', '될', '것', '같아', '너도'],
#  ['여자', '잠', '깐', '앉', '어'],
#  ['여자', '란것', '또한', '미칠것만', '같아'],
#  ['여자', '찾으면', '돼', '다짐해도', '내'],
#  ['여자', '처음부터', '어울리지', '않았어', '애써'],
#  ['여자', '때문에', '또', '하루를', '울기만'],
#  ['여자', '친굴', '사귈', '이유가', '없죠'],
#  ['여자', '마음은', '갈대라고', '선배들', '얘기를'],
#  ['여자', '친굴', '사귈', '이유가', '없죠'],
#  ['여자', '마음은', '갈대라고', '선배들', '얘기를'],
#  ['여자', '친굴', '사귈', '이유가', '없죠'],
#  ['여자', '마음은', '갈대라고', '선배들', '얘기를'],
#  ['여자', '친굴', '사귈', '이유가', '없죠'],
#  ['여자', '마음은', '갈대라고', '선배들', '얘기를'],
#  ['여자', '친굴', '사귈', '이유가', '없죠'],
#  ['여자', '마음은', '갈대라고', '선배들', '얘기를'],
#  ['여자', '싫다', '웃기지마', '다시', '해'],
#  ['여자', '만나도', '돼', '너란', '감옥에서'],
#  ['여자', '하난', '끝까지', '사랑해줄', '멋진'],
#  ['여자', 'It', 's', 'time', 'to'],
#  ['여자', 'It', 's', 'time', 'to'],
#  ['여자', '맘을', '훔치는', '뭔가', '너에겐'],
#  ['여자', '하난', '끝까지', '사랑해줄', '멋진'],
#  ['여자', '없다는', '내', '속삭임', 'you'],
#  ['여자', '중에', '딱', '너만이', '나의'],
#  ['여자', '중에', '딱', '너만이', '나의'],
#  ['여자', '옆에', '누워있니', '도대체', '몇'],
#  ['여자', '중', '난', '너를', '만난'],
#  ['여자', '옆에', '누워있니', '도대체', '몇'],
#  ['여자', '옆에', '누워있니', '도대체', '몇'],
#  ['여자', '없나요', '머리부터', '발끝까지', '완벽한'],
#  ['여자', '없나요', '머리부터', '발끝까지', '완벽한'],
#  ['여자', '없나요', '머리부터', '발끝까지', '완벽한'],
#  ['여자', '만나', '봤자야', '그래', '너'],
#  ['여자', '만나', '봤자야', '그래', '너'],
#  ['여자', '말고', '둘이', '두준이랑', '둘이'],
#  ['여자', '잊을', '거라', '말해도', '너란'],
#  ['여자', '다신', '보지', '말자', '다짐해봐도'],
#  ['여자', '잊을', '거라', '말해도', '너란'],
#  ['여자', '다신', '보지', '말자', '다짐해봐도'],
#  ['여자', '품에서', '나도', '행복할게', 'Girl'],
#  ['여자', '품에서', '나도', '행복', '할게'],
#  ['여자', '품에서', '나도', '행복', '할게'],
#  ['여자', '중에서', '빛이나', 'You', 're'],
#  ['여자', '사랑하는', '나', '나', '나란'],
#  ['여자', '너무너무', '예뻐요', '남의', '눈치'],
#  ['여자', 'jiggy', 'jiggy', '노는여자', '결국엔'],
#  ['여자', '지긋지긋해', '난', '가지가지해', '자꾸'],
#  ['여자', '지긋지긋해', '난', '가지가지해', '자꾸'],
#  ['여자', 'jiggy', 'jiggy', '노는여자', '결국엔'],
#  ['여자', '너무너무', '예뻐요', '남의', '눈치'],
#  ['여자', '패러디', '조금', '더', '에너지'],
#  ['여자', '패러디', '조금', '더', '에너지'],
#  ['여자', '땜에', '내가', '아아아아파', '소리질러'],
#  ['여자', '땜에', '내가', '아아아아파', '소리질러'],
#  ['여자', '정말', '어떡해', '어떡해', '너는'],
#  ['여자', '못', '찾아', '어디서', '이런'],
#  ['여자', '대단해', '너란', '여자', '불안해'],
#  ['여자', '불안해', '너란', '여자', 'You'],
#  ['여자', 'You', 'don', 't', 'even'],
#  ['여자', '대단해', '너란', '여자', '불안해'],
#  ['여자', '불안해', '너란', '여자', 'You'],
#  ['여자', 'You', 'don', 't', 'even'],
#  ['여자', '여전히', '너란', '여자', '사랑해'],
#  ['여자', '사랑해', '너란', '여자', 'Let'],
#  ['여자', 'Let', 'go', 'Time', 's'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '맘에', 'cry', 'and', 'cry'],
#  ['여자', '손', '대지', '마', '나만'],
#  ['여자', '손', '대지', '마', '나만'],
#  ['여자', '손', '대지', '마', '나만'],
#  ['여자', '킬러', '문자', '썼다', '지웠다가'],
#  ['여자', '항상', '네', '곁에', '있어'],
#  ['여자', '오빤', '너만', '사랑할래', 'Ah'],
#  ['여자', '킬러', '문자', '썼다', '지웠다가'],
#  ['여자', '싫다가도', '또', '보고', '싶겠지'],
#  ['여자', '아니란', '걸', '나만', '몰랐었나'],
#  ['여자', '이름으로', '저장해둔', '번호', '벌써'],
#  ['여자', '영원히', '나를', '모두', '가져'],
#  ['여자', '영원히', '나를', '모두', '가져'],
#  ['여자', '생겼냐고', '한참을', '뜸들이다', '글쎄'],
#  ['여자', '저리로', '가', '은행직원보다', '돈'],
#  ['여자', 'Sure', 'thing', 'Oh', '절로'],
#  ['여자', '말고', '너를', '갖고', '싶어'],
#  ['여자', '스타들의', 'Call', '그', '잘난'],
#  ['여자', '예쁜', '여자', '자꾸', '보이는'],
#  ['여자', '자꾸', '보이는', '걸', 'Yeah'],
#  ['여자', '착한', '여자', '가끔', '질리는'],
#  ['여자', '가끔', '질리는', '걸', 'Yeah'],
#  ['여자', '술', '다', '필요없네', '싹'],
#  ['여자', '술', '다', '필요없네', '싹'],
#  ['여자', '소개시켜', '달래', '듣고', '보니'],
#  ['여자', '찾아볼까', '외로운데', '나', '혼자'],
#  ['여자', '빨리빨리', '찾아요', '북', '치고'],
#  ['여자', '구하기', '하늘의', '별', '따기'],
#  ['여자', '빨리빨리', '찾아요', '북', '치고'],
#  ['여자', '많은', 'Club', '아니', 'No'],
#  ['여자', 'Now', 'is', 'good', 'girl'],
#  ['여자', 'Now', 'is', 'good', 'girl'],
#  ['여자', '너무나', '이상한걸', '자다', '깬'],
#  ['여자', '조금은', '특별한', '걸', '밤낮으로'],
#  ['여자', '너란', '여자', '너란', '여자'],
#  ['여자', '너란', '여자', 'yeah', '너라는'],
#  ['여자', 'yeah', '너라는', '여자', '부시시'],
#  ['여자', '부시시', '해도', '눈이', '부신'],
#  ['여자', '너란', '여자', '너란', '여자'],
#  ['여자', '너란', '여자', '매일', '만나도'],
#  ['여자', '매일', '만나도', '질리지', '않아'],
#  ['여자', '너무나', '이상한걸', '자다', '깬'],
#  ['여자', '조금은', '특별한', '걸', '밤낮으로'],
#  ['여자', '청바지가', '누구보다', '잘', '어울리는'],
#  ['여자', '희망사항이', '더', '필요', '없는'],
#  ['여자', '수지보다', '예쁜', '여자', '근데'],
#  ['여자', '근데', '입어도', '야한', '여자'],
#  ['여자', '비전있는', '여자', '느낌이', '장난'],
#  ['여자', '느낌이', '장난', '아닌', '너야'],
#  ['여자', 'La', 'la', 'la', 'la'],
#  ['여자', '넌', '내', '여자', '넌'],
#  ['여자', '넌', '내', '여자', '너라는'],
#  ['여자', '너라는', '여자', '부시시', '해도'],
#  ['여자', '부시시', '해도', '눈이', '부신'],
#  ['여자', '넌', '내', '여자', '넌'],
#  ['여자', '넌', '내', '여자', '매일'],
#  ['여자', '매일', '만나도', '질리지', '않아'],
#  ['여자', '같지', '않은', '태도와', '멘탈을'],
#  ['여자', '전부', '다', '니가', '만들어낸'],
#  ['여자', '설명해봐야', 'ho', '변명일', '뿐'],
#  ['여자', '너', '혹시라도', '돌아올', '생각'],
#  ['여자', '누나', '말야', '누나', '너'],
#  ['여자', '다룰때는', '풀러', '버려', '넥타이'],
#  ['여자', '친구라', '속여', 'girl', '너와'],
#  ['여자', '말고', 'your', 'the', 'only'],
#  ['여자', '만나는', '게', '근데', '너의'],
#  ['여자', '저', '여자', '시샘하잖아', '모두'],
#  ['여자', '시샘하잖아', '모두', '다', '사람들'],
#  ['여자', '저', '여자', '시샘하잖아', '모두'],
#  ['여자', '시샘하잖아', '모두', '다', '사람들'],
#  ['여자', '뭔가를', '버렸나봐', '갈', '길도'],
#  ['여자', '화끈한', '사랑', '찾아가', '어차피'],
#  ['여자', '백', '번', '말해', '또'],
#  ['여자', '백', '번', '받아줘', '내'],
#  ['여자', '앞에선', '좀비처럼', '심장도', '안'],
#  ['여자', '울린', '전과를', '물어', '자기야'],
#  ['여자', 'Hey', 'Baby', '난', '매일'],
#  ['여자', '많아도', '밤새도록', '너만', '찾아'],
#  ['여자', '애들', '다', '취했어', '난'],
#  ['여자', '나랑', '결혼해', '줄래요', 'Yeah'],
#  ['여자', '손에', '물', '안묻힐게', '그댄'],
#  ['여자', '붙잡아', 'Lady', '오던', '길'],
#  ['여자', '어차피', '모르던', '사람인데', '왜'],
#  ['여자', '어때', '잘못', '봤나', '보다'],
#  ['여자', '본심을', '수색', '중', '고작'],
#  ['여자', '때문에', '누구', '때문에', '호르몬'],
#  ['여자', '때문에', '누구', '때문에', '여자'],
#  ['여자', '때문에', '누구', '때문에', '호르몬'],
#  ['여자', '때문에', '여자는', '최고의', '선물이야'],
#  ['여자', '그래', '청', '반바지와', '흰'],
#  ['여자', '아', '진짜요', '어', '깨물어주고'],
#  ['여자', '아', '진짜요', '어', '깨물어주고'],
#  ['여자', '되어있을', '테니', 'Yeah', 'You'],
#  ['여자', '해라', 'Don', 't', 'pus'],
#  ['여자', '해라', '네', '주위엔', 'Player'],
#  ['여자', '해라', '기다릴', '수', '있어'],
#  ['여자', '해라', '나나나나나나나', '뭐하러', '나나나나나나'],
#  ['여자', '만나고', '싶어', '어디가야', '대체'],
#  ['여자', '앞에서만', '센', '척', '소문났어'],
#  ['여자', '난', '개띠라', '더', '본능을'],
#  ['여자', 'My', 'Baby', 'I', 'm'],
#  ['여자', '주인공이', '돼', 'Ready', 'action'],
#  ['여자', '주인공이', '돼', 'Ready', 'action'],
#  ['여자', '땜에', '우는', '나를', '아냐고'],
#  ['여자', '땜에', '우는', '나를', '아냐고'],
#  ['여자', '자체가', '내', 'Fetis', 'h'],
#  ['여자', '어렵다', '정말', 'Everybody', '모두'],
#  ['여자', '왠지', '좀', '궁금해', '자꾸'],
#  ['여자', '그녀를', '뒤쫓아', '이', '세상'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '날', '흔드는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '저기', '끌리는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '나를', '당기는', '여자'],
#  ['여자', '잠깐만', 'hey', '끌리는', '여자'],
#  ['여자', '무슨', '말을', '건네기도', '전에'],
#  ['여자', '그녀를', '뒤쫓아', '이', '세상'],
#  ['여자', '어쩌면', '너도', '날', '봤는지'],
#  ['여자', '그녀를', '뒤쫓아', '이', '세상'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '날', '흔드는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '저기', '끌리는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '나를', '당기는', '여자'],
#  ['여자', '잠깐만', 'hey', '끌리는', '여자'],
#  ['여자', 'Hey', 'girl', 'I', 'don'],
#  ['여자', '왠지', '좀', '궁금해', '자꾸'],
#  ['여자', '그녀를', '뒤쫓아', '이', '세상'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '날', '흔드는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '저기', '끌리는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '나를', '당기는', '여자'],
#  ['여자', '잠깐만', 'hey', '끌리는', '여자'],
#  ['여자', '무슨', '말을', '건네기도', '전에'],
#  ['여자', '그녀를', '뒤쫓아', '이', '세상'],
#  ['여자', '어쩌면', '너도', '날', '봤는지'],
#  ['여자', '그녀를', '뒤쫓아', '이', '세상'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '날', '흔드는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '저기', '끌리는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '나를', '당기는', '여자'],
#  ['여자', '잠깐만', 'hey', '끌리는', '여자'],
#  ['여자', '이걸', '범죄라', '할', '수'],
#  ['여자', '왠지', '좀', '궁금해', '자꾸'],
#  ['여자', '그녀를', '뒤쫓아', '이', '세상'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '날', '흔드는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '저기', '끌리는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '나를', '당기는', '여자'],
#  ['여자', '잠깐만', 'hey', '끌리는', '여자'],
#  ['여자', '무슨', '말을', '건네기도', '전에'],
#  ['여자', '그녀를', '뒤쫓아', '이', '세상'],
#  ['여자', '어쩌면', '너도', '날', '봤는지'],
#  ['여자', '그녀를', '뒤쫓아', '이', '세상'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '날', '흔드는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '저기', '끌리는', '여자'],
#  ['여자', '뚜루뚜뚜뚜뚜두뚜', '나를', '당기는', '여자'],
#  ['여자', '잠깐만', 'hey', '끌리는', '여자'],
#  ['여자', 'I', 'don', 't', 'care'],
#  ['여자', '애타는', '내', '맘을', '넌'],
#  ['여자', '모두', 'Hello', 'Hot', '뜨거운'],
#  ['여자', '모두', 'Hello', 'Hot', '뜨거운'],
#  ['여자', '모두', 'Hello', '모두', '다'],
#  ['여자', '모두', 'Hello', 'Hot', '뜨거운'],
#  ['여자', '다', '같이', '밤낮없이', 'keep'],
#  ['여자', '다', '같이', '밤낮없이', 'keep'],
#  ['여자', '못', '만날', '상이래', '입만'],
#  ['여자', 'You', 're', 'the', 'one'],
#  ['여자', 'You', 're', 'the', 'one'],
#  ['여자', '중에', '내', '짝은', '누군지'],
#  ['여자', '여우짓', '보고', '싶어', '그랬어'],
#  ['여자', '여우짓', '보고', '싶어', '그랬어'],
#  ['여자', '돼', '줄래', 'dancing', 'with'],
#  ['여자', '계속', '그렇게', '웃으며', '계속'],
#  ['여자', '미저리', '심장박동의', '속도', '느껴지는'],
#  ['여자', '돼줄래', 'Baby', 'come', 'ride'],
#  ['여자', '돼줄래', '어디서든', '네', '옆에'],
#  ['여자', '돼줄래', '어디서든', '네', '옆에'],
#  ['여자', '돼줄래', '어디서든', '네', '옆에'],
#  ['여자', '돼줄래', 'Baby', 'come', 'ride'],
#  ['여자', '돼줄래', '어디서든', '네', '옆에'],
#  ['여자', '돼줄래', '어디서든', '네', '옆에'],
#  ['여자', '돼줄래', '어디서든', '네', '옆에'],
#  ['여자', '메세지', 'right', '우리', '사이'],
#  ['여자', '뜨거운', '날', '만나', '증발했나봐'],
#  ['여자', '그래', '다', '됐다', '갈대일']]

# %%
# 하나의 리스트로 만들어주기
result_one2 = sum(result2, [])
result_one2
# Out:
# ['여자',
#  '없다고',
#  'Lovin',
#  'u',
#  '널',
#  '여자',
#  '앞에',
#  '이런',
#  '내모습',
#  '본적',
#  '여자',
#  '내게',
#  '도와',
#  '달라고',
#  '울며',
#  '여자',
#  '하나',
#  '때문에',
#  '깨버릴수는',
#  '없는거잖아',
#  '여자',
#  '앞에',
#  '이런',
#  '내모습',
#  '본적',
#  '여자',
#  '생겼다는게',
#  '이렇게',
#  '헤어',
#  '나올',
#  '여자',
#  '내게',
#  '도와',
#  '달라고',
#  '울며',
#  '여자',
#  '믿을수도',
#  '없는',
#  '우리만의',
#  '썸씽',
#  '여자',
#  '얼마든지',
#  '옆에',
#  '둘수',
#  '있는',
#  '여자',
#  '잘생긴',
#  '남자',
#  '팔짱',
#  '끼고',
#  '여자',
#  '서로의',
#  '개성을',
#  '살리자',
#  '신세대여',
#  '여자',
#  '여자',
#  '여자는',
#  '감정이',
#  '풍부한',
#  '여자',
#  '여자는',
#  '감정이',
#  '풍부한',
#  '사람이지',
#  '여자',
#  '대책',
#  '안',
#  '서',
#  '부모님은',
#  '여자',
#  '왜',
#  '나를',
#  '모른척',
#  '할까',
#  '여자',
#  '언짢은',
#  '기분에',
#  '나가려',
#  '할때',
#  '여자',
#  '애인은',
#  '아닐까',
#  '바로',
#  '그',
#  '여자',
#  '입을',
#  '다물지',
#  '못해',
#  '너무',
#  '여자',
#  '옆을',
#  '지나서',
#  '그냥',
#  '사라져갔어',
#  '여자',
#  '내',
#  '친구',
#  '애인이야',
#  '바로',
#  '여자',
#  '입을',
#  '다물지못해',
#  '너무',
#  '미안해서',
#  '여자',
#  '친구가',
#  '만나자고',
#  '하면',
#  '핑계만',
#  '여자',
#  '누구야라는',
#  '말소리에',
#  '놀라',
#  '정신차리고',
#  '여자',
#  '처음이야',
#  '나',
#  '정말',
#  '힘들었어',
#  '여자',
#  '혹은',
#  '내가',
#  '반한',
#  '여자',
#  '여자',
#  '있어도',
#  '아무말',
#  '못하고',
#  '바보처럼',
#  '여자',
#  '내',
#  '터프함에',
#  '모두',
#  '다',
#  '여자',
#  '저',
#  '여자',
#  '모두다',
#  '내',
#  '여자',
#  '모두다',
#  '내',
#  '여자이길',
#  '바래',
#  '여자',
#  '저',
#  '여자',
#  '모두다',
#  '내',
#  '여자',
#  '모두다',
#  '내',
#  '여자이길',
#  '바래',
#  '여자',
#  '혹은',
#  '내가',
#  '반한',
#  '여자',
#  '여자',
#  '있어도',
#  '아무말',
#  '못하고',
#  '바보처럼',
#  '여자',
#  '내',
#  '터프함에',
#  '모두',
#  '다',
#  '여자',
#  '저',
#  '여자',
#  '모두다',
#  '내',
#  '여자',
#  '모두다',
#  '내',
#  '여자이길',
#  '바래',
#  '여자',
#  '저',
#  '여자',
#  '모두다',
#  '내',
#  '여자',
#  '모두다',
#  '내',
#  '여자이길',
#  '바래',
#  '여자',
#  '같던',
#  '니가',
#  '그',
#  '동안',
#  '여자',
#  '너도',
#  '이제',
#  '사랑을',
#  '아네',
#  '여자',
#  '친구들',
#  '너',
#  '하나',
#  '믿고',
#  '여자',
#  '친구들',
#  '너',
#  '하나',
#  '믿고',
#  '여자',
#  '처음이야',
#  '나',
#  '정말',
#  '힘들었어',
#  '여자',
#  '일',
#  '년을',
#  '못',
#  '넘겼지',
#  '여자',
#  '늠름한',
#  '남자',
#  '원한다면',
#  '진짜',
#  '여자',
#  '보이잖아',
#  '그깟',
#  '자존심',
#  '버릴땐',
#  '여자',
#  '어디없나',
#  '매일',
#  '이렇게',
#  '꿈꾸는',
#  '여자',
#  '주인공',
#  '번진',
#  '마스카라는',
#  '지우고',
#  '여자',
#  '많은데',
#  '양심의',
#  '가책',
#  '때문에',
#  '여자',
#  '중에',
#  '왜',
#  '하필이면',
#  '너냐고',
#  '여자',
#  '함께해도',
#  '가슴이',
#  '자꾸',
#  '허전해',
#  '여자',
#  '내',
#  '앞에선',
#  '통하지',
#  '않았어',
#  '여자',
#  '중에',
#  '정말',
#  '못생긴',
#  '여자라곤',
#  '여자',
#  '모두다',
#  '정말',
#  '눈부시게',
#  '예뻤지만',
#  '여자',
#  '왜',
#  '모두다',
#  '예쁜거야',
#  '왜',
#  '여자',
#  '데려가줘',
#  '나를',
#  '떠난',
#  '여자들이',
#  '여자',
#  '왜',
#  '모두',
#  '다',
#  '이쁜거야',
#  '여자',
#  '만나나',
#  '항상',
#  '감시한대',
#  '어쩌다',
#  '여자',
#  '만나나',
#  '항상',
#  '감시한대',
#  '어쩌다',
#  '여자',
#  '많은데',
#  '양심의',
#  '가책',
#  '때문에',
#  '여자',
#  '세상',
#  '가장',
#  '폼',
#  '나는',
#  '여자',
#  '터져',
#  '버릴',
#  '것만',
#  '같은',
#  '여자',
#  '없니',
#  '나중에',
#  '딴소리마',
#  '다',
#  '여자',
#  '낯익은',
#  '그',
#  '얼굴',
#  '집에',
#  '여자',
#  'for',
#  'life',
#  '수많은',
#  '사람들',
#  '여자',
#  '화를',
#  '내봐도',
#  '니가',
#  '소릴',
#  '여자',
#  '어젠',
#  '니',
#  '얘길',
#  '한',
#  '여자',
#  '화를',
#  '내봐도',
#  '니가',
#  '소릴',
#  '여자',
#  'You',
#  're',
#  'bad',
#  'bad',
#  '여자',
#  '화를',
#  '내봐도',
#  '니가',
#  '소릴',
#  '여자',
#  '좋은',
#  '냄새도',
#  '그녀의',
#  '두',
#  '여자',
#  '못들은',
#  '척',
#  '해도',
#  '두',
#  '여자',
#  'You',
#  're',
#  'bad',
#  'bad',
#  '여자',
#  '화를',
#  '내봐도',
#  '니가',
#  '소릴',
#  '여자',
#  '어젠',
#  '니',
#  '얘길',
#  '한',
#  '여자',
#  '화를',
#  '내봐도',
#  '니가',
#  '소릴',
#  '여자',
#  'You',
#  're',
#  'bad',
#  'bad',
#  '여자',
#  '화를',
#  '내봐도',
#  '니가',
#  '소릴',
#  '여자',
#  '좋은',
#  '냄새도',
#  '그녀의',
#  '두',
#  '여자',
#  '못들은',
#  '척',
#  '해도',
#  '두',
#  '여자',
#  'You',
#  're',
#  'bad',
#  'bad',
#  '여자',
#  '난',
#  '그대로인',
#  '걸요',
#  '너무',
#  '여자',
#  '난',
#  '그대로인',
#  '걸요',
#  '너무',
#  '여자',
#  '난',
#  '그대로인',
#  '걸요',
#  '너무',
#  '여자',
#  '난',
#  '그대로인',
#  '걸요',
#  '너무',
#  '여자',
#  '난',
#  '그대로인',
#  '걸요',
#  '너무',
#  '여자',
#  '난',
#  '그대로인',
#  '걸요',
#  '너무',
#  '여자',
#  '내가',
#  '말했던',
#  '즐거웠던',
#  '시간',
#  '여자',
#  '만날',
#  '수',
#  '있을',
#  '것',
#  '여자',
#  '만날',
#  '수',
#  '있을',
#  '것같아',
#  '여자',
#  '앞에',
#  '서면',
#  '다르지',
#  '사랑은',
#  '여자',
#  '앞에',
#  '서면',
#  '다르지',
#  '사랑은',
#  '여자',
#  '앞에',
#  '서면',
#  '다르지',
#  '사랑은',
#  '여자',
#  '앞에',
#  '서면',
#  '다르지',
#  '사랑은',
#  '여자',
#  '앞에',
#  '서면',
#  '다르지',
#  '사랑은',
#  '여자',
#  '앞에',
#  '서면',
#  '다르지',
#  '사랑은',
#  '여자',
#  '때문에',
#  '고생하네',
#  '참',
#  '딱해',
#  '여자',
#  '지나치게',
#  '한',
#  '걸',
#  '너만을',
#  '여자',
#  '별로',
#  '큰',
#  '의미가',
#  '없는걸',
#  '여자',
#  '별로',
#  '큰',
#  '의미가',
#  '없는걸',
#  '여자',
#  '별로',
#  '큰',
#  '의미가',
#  '없는걸',
#  '여자',
#  '였다고',
#  '바보같이',
#  '내가',
#  '너에게',
#  '여자',
#  '도대체',
#  '어떤',
#  '여잔지',
#  '넌',
#  '여자',
#  '너무나',
#  '많은',
#  '남자',
#  '울렸던',
#  '여자',
#  '너의',
#  '마음을',
#  '모두',
#  '다',
#  '여자',
#  '였다고',
#  '바보같이',
#  '내가',
#  '너에게',
#  '여자',
#  '별로',
#  '큰',
#  '의미가',
#  '없는걸',
#  '여자',
#  '만나길',
#  '지금껏',
#  '기다려온',
#  '보람이',
#  '여자',
#  '만나길',
#  '지금껏',
#  '기다려온',
#  '보람이',
#  '여자',
#  '니가',
#  '책속에서',
#  '정말',
#  '찾아봐봐',
#  '여자',
#  '바로',
#  '너라는',
#  '걸',
#  '이것저것',
#  '여자',
#  '또만날',
#  '이유가',
#  '없어',
#  '세상',
#  '여자',
#  '만나도',
#  '결코',
#  '널',
#  '잊는건',
#  '여자',
#  '만나도',
#  '결코',
#  '널',
#  '잊는건',
#  '여자',
#  '아니잖아',
#  '하지만',
#  '내가',
#  '싫어',
#  '여자',
#  '없어',
#  '난',
#  '그래',
#  '그',
#  '여자',
#  '기다리며',
#  '살아왔거든',
#  '너라면은',
#  '뭐든지',
#  '여자',
#  '지나가도',
#  '나는',
#  '그저',
#  '너',
#  '여자',
#  '사인',
#  '친구가',
#  '될',
#  '수',
#  '여자',
#  '못',
#  '말리는',
#  '여자',
#  '괜찮은',
#  '여자',
#  '괜찮은',
#  '여자',
#  '나를',
#  '위해주는',
#  '여자',
#  '나를',
#  '위해주는',
#  '여자',
#  '애교',
#  '여자',
#  '애교',
#  '많은',
#  '여자',
#  '꿈이',
#  '여자',
#  '꿈이',
#  '너무',
#  '많은',
#  '여자',
#  '여자',
#  '순수한',
#  '여자',
#  '내가',
#  '원하는',
#  '여자',
#  '내가',
#  '원하는',
#  '여자',
#  '완벽한',
#  '여자',
#  '완벽한',
#  '여자',
#  '손이',
#  '예쁜',
#  '여자',
#  '손이',
#  '예쁜',
#  '여자',
#  '옷',
#  '여자',
#  '옷',
#  '잘',
#  '입는',
#  '여자',
#  '여자',
#  '감각',
#  '있는',
#  '여자',
#  '인격',
#  '여자',
#  '인격',
#  '있는',
#  '여자',
#  '나를',
#  '여자',
#  '나를',
#  '나만을',
#  '영원히',
#  '사랑해',
#  '여자',
#  '이런',
#  '여자는',
#  '세상엔',
#  '없다',
#  '여자',
#  '근데',
#  '아닌데',
#  '뭔가',
#  '다른데',
#  '여자',
#  '근데',
#  '아닌데',
#  '뭔가',
#  '다른데',
#  '여자',
#  '킬러',
#  '문자',
#  '썼다',
#  '지웠다가',
#  '여자',
#  '일색이란',
#  '생각들은',
#  '보편적',
#  '도도하게',
#  '여자',
#  '얼굴은',
#  '안',
#  '봐',
#  '내가',
#  '여자',
#  '화목토',
#  '쟤가',
#  '내',
#  '여자',
#  '여자',
#  '오빠',
#  '나도',
#  '데려가',
#  '일요일',
#  '여자',
#  '킬러',
#  '문자',
#  '썼다',
#  '지웠다가',
#  '여자',
#  '일색이란',
#  '생각들은',
#  '보편적',
#  '도도하게',
#  '여자',
#  '일색이란',
#  '생각들은',
#  '보편적',
#  '도도하게',
#  '여자',
#  '일색이란',
#  '생각들은',
#  '보편적',
#  '도도하게',
#  '여자',
#  '만날',
#  '때가',
#  '아닌',
#  '듯',
#  '여자',
#  '얼굴은',
#  '안',
#  '봐',
#  '내가',
#  '여자',
#  '화목토',
#  '쟤가',
#  '내',
#  '여자',
#  '여자',
#  '오빠',
#  '나도',
#  '데려가',
#  '일요일',
#  '여자',
#  '일색이란',
#  '생각들은',
#  '보편적',
#  '도도하게',
#  '여자',
#  '다시',
#  '만날',
#  '순',
#  '없지만',
#  '여자',
#  '찾느니',
#  '차라리',
#  '나',
#  '그냥',
#  '여자',
#  '몰라',
#  'I',
#  'm',
#  'your',
#  '여자',
#  '보고',
#  '살짝',
#  '곁눈질도',
#  '해보고',
#  '여자',
#  '될',
#  '것',
#  '같아',
#  '너도',
#  '여자',
#  '잠',
#  '깐',
#  '앉',
#  '어',
#  '여자',
#  '란것',
#  '또한',
#  '미칠것만',
#  '같아',
#  '여자',
#  '찾으면',
#  '돼',
#  '다짐해도',
#  '내',
#  '여자',
#  '처음부터',
#  '어울리지',
#  '않았어',
#  '애써',
#  '여자',
#  '때문에',
#  '또',
#  '하루를',
#  '울기만',
#  '여자',
#  '친굴',
#  '사귈',
#  '이유가',
#  '없죠',
#  '여자',
#  '마음은',
#  '갈대라고',
#  '선배들',
#  '얘기를',
#  '여자',
#  '친굴',
#  '사귈',
#  '이유가',
#  '없죠',
#  '여자',
#  '마음은',
#  '갈대라고',
#  '선배들',
#  '얘기를',
#  '여자',
#  '친굴',
#  '사귈',
#  '이유가',
#  '없죠',
#  '여자',
#  '마음은',
#  '갈대라고',
#  '선배들',
#  '얘기를',
#  '여자',
#  '친굴',
#  '사귈',
#  '이유가',
#  '없죠',
#  '여자',
#  '마음은',
#  '갈대라고',
#  '선배들',
#  '얘기를',
#  '여자',
#  '친굴',
#  '사귈',
#  '이유가',
#  '없죠',
#  '여자',
#  '마음은',
#  '갈대라고',
#  '선배들',
#  '얘기를',
#  '여자',
#  '싫다',
#  '웃기지마',
#  '다시',
#  '해',
#  '여자',
#  '만나도',
#  '돼',
#  '너란',
#  '감옥에서',
#  '여자',
#  '하난',
#  '끝까지',
#  '사랑해줄',
#  '멋진',
#  '여자',
#  'It',
#  's',
#  'time',
#  'to',
#  '여자',
#  'It',
#  's',
#  'time',
#  'to',
#  '여자',
#  '맘을',
#  '훔치는',
#  '뭔가',
#  '너에겐',
#  '여자',
#  '하난',
#  '끝까지',
#  '사랑해줄',
#  '멋진',
#  '여자',
#  '없다는',
#  '내',
#  '속삭임',
#  'you',
#  '여자',
#  '중에',
#  '딱',
#  '너만이',
#  '나의',
#  '여자',
#  '중에',
#  '딱',
#  '너만이',
#  '나의',
#  '여자',
#  '옆에',
#  '누워있니',
#  '도대체',
#  '몇',
#  '여자',
#  '중',
#  '난',
#  '너를',
#  '만난',
#  '여자',
#  '옆에',
#  '누워있니',
#  '도대체',
#  '몇',
#  '여자',
#  '옆에',
#  '누워있니',
#  '도대체',
#  '몇',
#  '여자',
#  '없나요',
#  '머리부터',
#  '발끝까지',
#  '완벽한',
#  '여자',
#  '없나요',
#  '머리부터',
#  '발끝까지',
#  '완벽한',
#  '여자',
#  '없나요',
#  '머리부터',
#  '발끝까지',
#  '완벽한',
#  '여자',
#  '만나',
#  '봤자야',
#  '그래',
#  '너',
#  '여자',
#  '만나',
#  '봤자야',
#  '그래',
#  '너',
#  '여자',
#  '말고',
#  '둘이',
#  '두준이랑',
#  '둘이',
#  '여자',
#  '잊을',
#  '거라',
#  '말해도',
#  '너란',
#  '여자',
#  '다신',
#  '보지',
#  '말자',
#  '다짐해봐도',
#  '여자',
#  '잊을',
#  '거라',
#  '말해도',
#  '너란',
#  '여자',
#  '다신',
#  '보지',
#  '말자',
#  '다짐해봐도',
#  '여자',
#  '품에서',
#  '나도',
#  '행복할게',
#  'Girl',
#  '여자',
#  '품에서',
#  '나도',
#  '행복',
#  '할게',
#  '여자',
#  '품에서',
#  '나도',
#  '행복',
#  '할게',
#  '여자',
#  '중에서',
#  '빛이나',
#  'You',
#  're',
#  '여자',
#  '사랑하는',
#  '나',
#  '나',
#  '나란',
#  '여자',
#  '너무너무',
#  '예뻐요',
#  '남의',
#  '눈치',
#  '여자',
#  'jiggy',
#  'jiggy',
#  '노는여자',
#  '결국엔',
#  ...]

# %%
# 두 음절 이상으로 묶어준다.
more_words1 = []
for i in result:
    for v in i :
        if len(v) > 1:
            more_words1.append(v)

# %%
from collections import Counter

Counter(more_words1).most_common(20)
# Out:
# [('여자', 268),
#  ('맘을', 19),
#  ('몰라', 16),
#  ('남자', 13),
#  ('oh', 9),
#  ('그런', 9),
#  ('다른', 9),
#  ('같은', 9),
#  ('해봐', 8),
#  ('내가', 8),
#  ('나를', 8),
#  ('You', 7),
#  ('사랑해', 7),
#  ('똑같은', 7),
#  ('외계인처럼', 6),
#  ('지구를', 6),
#  ('탓하지만', 6),
#  ('boys', 6),
#  ('너랑', 6),
#  ('조금만', 6)]

# %%
# 두 음절 이상으로 묶어준다.
more_words2 = []
for i in result2:
    for v in i :
        if len(v) > 1:
            more_words2.append(v)

# %%
from collections import Counter

Counter(more_words2).most_common(20)
# Out:
# [('여자', 482),
#  ('cry', 28),
#  ('뚜루뚜뚜뚜뚜두뚜', 18),
#  ('나를', 16),
#  ('모두', 16),
#  ('너란', 15),
#  ('맘에', 14),
#  ('and', 14),
#  ('때문에', 12),
#  ('내가', 12),
#  ('You', 12),
#  ('끌리는', 12),
#  ('세상', 11),
#  ('옆에', 10),
#  ('모두다', 10),
#  ('너무', 9),
#  ('니가', 9),
#  ('그녀를', 9),
#  ('뒤쫓아', 9),
#  ('앞에', 8)]

# %%
i = 0
result5_1 = []
for i in range(len(indices)):
    next_word_1 = tokens_all2[indices[i]:indices[i] + 5]
    result5_1.append(next_word_1)
    i+=1
    continue

# %%
result5_1
# Out:
# [['나', '홀로', '방황하고', '있다', '재작년'],
#  ['돌아와줘', 'pleas', 'e', 'come', 'to'],
#  ['다시', '혼자가', '되긴', '나', '정말'],
#  ['이제와', '허전함일', '줄은', '정말로', '난'],
#  ['너무', '부끄러워', '하지말구', 'shake', 'that'],
#  ['이렇게', '그냥', '끝낼', '수도', '있어'],
#  ['그리던', 'magic', '같은', '영상', '조금씩'],
#  ['향기뿐야', '끝나지', '않아', '언제나', '저'],
#  ['이대로', '버려진', '내모습', '언제까지라도', '널'],
#  ['넌', '너무', '답답해', '어젯밤에', '너는'],
#  ['your', 'hands', 'up', '오랫만에', '기분이'],
#  ['ah', '정말', '바보같아', '내', '맘을'],
#  ['깨달았어', '한번만', '한번만', '기회를', '주겠니'],
#  ['말했었지', '그', '어떤', '사랑도', '할'],
#  ['함께', '그대여', 'you', 'are', 'the'],
#  ['the', 'sweetes', 't', 'thing', '그대만을'],
#  ['난', '진절', '넌더리', '나네', '가네'],
#  ['없어', '나', '혼자', '당할수', '없어'],
#  ['너희의', '눈과', '귀와', '모든것을', '우리에게'],
#  ['내', '맘속', '얼마나', '수많은', '날을'],
#  ['않아', '이', '믿음이라면', '아무에게도', '뒤지지'],
#  ['smith', 'wow', 'wow', 'wes', 't'],
#  ['really', 'be', 'a', 'shooting', 'star'],
#  ['묶이고', '또', '조이고', '붙어버린', '우린'],
#  ['얼마나', '고마운', '지', '행복한', '지'],
#  ['있어', '너만', '오면', '돼', '나'],
#  ['건', '처음이니까', '삼킨', '눈물에', '맘이'],
#  ['us', 'ed', 'to', 'know', 'Where'],
#  ['웃으면서', '살아야', '돼', '제발', '울지말고'],
#  ['날까지', '까만', '눈동자', '까만', '생머리'],
#  ['on', 'let', 'me', 'here', 'say'],
#  ['우린', '웃을', '수', '있는', '웃을'],
#  ['그대', 'I', 'll', 'get', 'you'],
#  ['말이지만', '너를', '영원토록', '아끼며', '사랑을'],
#  ['감당할', '수', '없겠어', '내겐', '가진게'],
#  ['from', 'the', 'riches', 't', 'to'],
#  ['s', 'get', 'to', 'it', 'come'],
#  ['모두', '견뎌보겠어', '원하는걸', '이룰수있겠지', 'I'],
#  ['벗고', '나를', '보며', '유혹하는', '여자들의'],
#  ['Good', 'night', 'Good', 'night', 'Good'],
#  ['오직', '그대만이', '필요해', '오직', '당신만'],
#  ['보일까', '깊이', '베인', '상처는', '아물지'],
#  ['나만의', '여행', 'Shall', 'we', 'take'],
#  ['걸', '걸', '걸', 'Bounce', 'to'],
#  ['to', 'you', '내', '가슴은', '널'],
#  ['보고봐도', '보고봐도', '보고봐도', '나', '밖에'],
#  ['보나마나', '보나마나', '보나마나', 'Baby', 'you'],
#  ['수', '있다면', '메마른', '사막', '어딘가에'],
#  ['멈추지', '않게', '한', '가닥', '힘이'],
#  ['멀리', '보이는', '끝', 'I', 'm'],
#  ['내일', '닿게', '될', '거긴', '어디까지'],
#  ['my', 'friends', '잊지', '못할', '거야'],
#  ['멋진', '세상에', 'I', 'm', 'alive'],
#  ['so', 'mysterious', 'lady', 'so', 'mysterious'],
#  ['솔직하게', '그대', '맘을', '보여줘요', 'baby'],
#  ['시작도', '안했었다면', '많은', '약속도', '안했었다면'],
#  ['지긋지긋해', '숨이', '막혀', '견딜', '수']]

# %%
i = 0
result5_2 = []
for i in range(len(indices)):
    next_word_1 = tokens_all2[indices[i]:indices[i] + 5]
    result2.append(next_word_1)
    i+=1
    continue

# %%
i = 0
indices_value = {indices[i], tokens_all[indices[i]]}
indices_value
# Out:
# {59507, '여자는'}

# %%
i = 0
for i in indices:
    indices_value = {indices[i]: tokens_all[indices[i]]}
    i = i+1
#     indices_value[indices[i]] = str(tokens_all[indices[i]])
    print(indices_value)
# next_word_all = tokens_all[tokens_all.index(indices):tokens_all.index(indices) + 5]
# next_word_all

# %%
indices[1]

# %%
# 단어 사전에서 상위 10개만 보기
vocab = model.wv.vocab
sorted(vocab, key=vocab.get, reverse=True)[:10]

# %%
# word2vec 모델 학습에 로그를 찍을 수 있도록 합니다.

import logging
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s', 
    level=logging.INFO)

# %%
# 초기화 및 모델 학습
from gensim.models import word2vec

# 모델 학습
model = word2vec.Word2Vec(tokens, min_count=1)  # word2vec에 tokens을 넣어주고, min_count =1 로 해주면 최소한 1번들어가 있으면 뽑히게 한다. 

model
# Out:
# 2018-09-13 22:02:09,669 : INFO : collecting all words and their counts
# 2018-09-13 22:02:09,671 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-09-13 22:02:09,928 : INFO : collected 56679 word types from a corpus of 927789 raw words and 4025 sentences
# 2018-09-13 22:02:09,929 : INFO : Loading a fresh vocabulary
# 2018-09-13 22:02:10,267 : INFO : min_count=1 retains 56679 unique words (100% of original 56679, drops 0)
# 2018-09-13 22:02:10,268 : INFO : min_count=1 leaves 927789 word corpus (100% of original 927789, drops 0)
# 2018-09-13 22:02:10,473 : INFO : deleting the raw counts dictionary of 56679 items
# 2018-09-13 22:02:10,476 : INFO : sample=0.001 downsamples 36 most-common words
# 2018-09-13 22:02:10,478 : INFO : downsampling leaves estimated 869858 word corpus (93.8% of prior 927789)
# 2018-09-13 22:02:10,697 : INFO : estimated required memory for 56679 words and 100 dimensions: 73682700 bytes
# 2018-09-13 22:02:10,698 : INFO : resetting layer weights
# 2018-09-13 22:02:11,327 : INFO : training model with 3 workers on 56679 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-09-13 22:02:12,344 : INFO : EPOCH 1 - PROGRESS: at 82.04% examples, 702401 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:12,559 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:12,571 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:12,574 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:12,575 : INFO : EPOCH - 1 : training on 927789 raw words (869960 effective words) took 1.2s, 698620 effective words/s
# 2018-09-13 22:02:13,585 : INFO : EPOCH 2 - PROGRESS: at 77.69% examples, 670519 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:13,820 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:13,827 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:13,839 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:13,840 : INFO : EPOCH - 2 : training on 927789 raw words (869892 effective words) took 1.3s, 689512 effective words/s
# 2018-09-13 22:02:14,854 : INFO : EPOCH 3 - PROGRESS: at 87.40% examples, 753137 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:14,990 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:15,012 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:15,023 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:15,024 : INFO : EPOCH - 3 : training on 927789 raw words (869922 effective words) took 1.2s, 738115 effective words/s
# 2018-09-13 22:02:16,042 : INFO : EPOCH 4 - PROGRESS: at 86.48% examples, 740252 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:16,179 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:16,189 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:16,190 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:16,190 : INFO : EPOCH - 4 : training on 927789 raw words (869899 effective words) took 1.2s, 749145 effective words/s
# 2018-09-13 22:02:17,212 : INFO : EPOCH 5 - PROGRESS: at 66.76% examples, 569425 words/s, in_qsize 6, out_qsize 0
# 2018-09-13 22:02:17,818 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:17,821 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:17,835 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:17,836 : INFO : EPOCH - 5 : training on 927789 raw words (869688 effective words) took 1.6s, 533521 effective words/s
# 2018-09-13 22:02:17,838 : INFO : training on a 4638945 raw words (4349361 effective words) took 6.5s, 668118 effective words/s

# %%
# 초기화 및 모델 학습
from gensim.models import word2vec

# 모델 학습
model2 = word2vec.Word2Vec(tokens2, min_count=1)  # word2vec에 tokens을 넣어주고, min_count =1 로 해주면 최소한 1번들어가 있으면 뽑히게 한다. 

model2
# Out:
# 2018-09-13 22:02:19,569 : INFO : collecting all words and their counts
# 2018-09-13 22:02:19,571 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-09-13 22:02:20,030 : INFO : collected 99548 word types from a corpus of 1897565 raw words and 7949 sentences
# 2018-09-13 22:02:20,031 : INFO : Loading a fresh vocabulary
# 2018-09-13 22:02:20,563 : INFO : min_count=1 retains 99548 unique words (100% of original 99548, drops 0)
# 2018-09-13 22:02:20,564 : INFO : min_count=1 leaves 1897565 word corpus (100% of original 1897565, drops 0)
# 2018-09-13 22:02:20,926 : INFO : deleting the raw counts dictionary of 99548 items
# 2018-09-13 22:02:20,929 : INFO : sample=0.001 downsamples 37 most-common words
# 2018-09-13 22:02:20,930 : INFO : downsampling leaves estimated 1782402 word corpus (93.9% of prior 1897565)
# 2018-09-13 22:02:21,387 : INFO : estimated required memory for 99548 words and 100 dimensions: 129412400 bytes
# 2018-09-13 22:02:21,388 : INFO : resetting layer weights
# 2018-09-13 22:02:22,657 : INFO : training model with 3 workers on 99548 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-09-13 22:02:23,675 : INFO : EPOCH 1 - PROGRESS: at 42.61% examples, 671933 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:24,679 : INFO : EPOCH 1 - PROGRESS: at 77.57% examples, 657777 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:25,637 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:25,646 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:25,658 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:25,659 : INFO : EPOCH - 1 : training on 1897565 raw words (1782161 effective words) took 3.0s, 594910 effective words/s
# 2018-09-13 22:02:26,665 : INFO : EPOCH 2 - PROGRESS: at 26.22% examples, 417419 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:27,677 : INFO : EPOCH 2 - PROGRESS: at 55.60% examples, 447488 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:28,677 : INFO : EPOCH 2 - PROGRESS: at 92.68% examples, 544230 words/s, in_qsize 6, out_qsize 0
# 2018-09-13 22:02:28,864 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:28,868 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:28,868 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:28,869 : INFO : EPOCH - 2 : training on 1897565 raw words (1782164 effective words) took 3.2s, 555721 effective words/s
# 2018-09-13 22:02:29,885 : INFO : EPOCH 3 - PROGRESS: at 47.05% examples, 745562 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:30,893 : INFO : EPOCH 3 - PROGRESS: at 90.79% examples, 793810 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:31,128 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:31,146 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:31,156 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:31,157 : INFO : EPOCH - 3 : training on 1897565 raw words (1782089 effective words) took 2.3s, 780232 effective words/s
# 2018-09-13 22:02:32,172 : INFO : EPOCH 4 - PROGRESS: at 32.70% examples, 521322 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:33,189 : INFO : EPOCH 4 - PROGRESS: at 65.05% examples, 533576 words/s, in_qsize 6, out_qsize 0
# 2018-09-13 22:02:34,196 : INFO : EPOCH 4 - PROGRESS: at 95.55% examples, 561145 words/s, in_qsize 6, out_qsize 0
# 2018-09-13 22:02:34,344 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:34,348 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:34,383 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:34,385 : INFO : EPOCH - 4 : training on 1897565 raw words (1782404 effective words) took 3.2s, 554667 effective words/s
# 2018-09-13 22:02:35,403 : INFO : EPOCH 5 - PROGRESS: at 44.66% examples, 709815 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:36,414 : INFO : EPOCH 5 - PROGRESS: at 71.44% examples, 591766 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:37,428 : INFO : EPOCH 5 - PROGRESS: at 96.49% examples, 565255 words/s, in_qsize 5, out_qsize 0
# 2018-09-13 22:02:37,595 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-13 22:02:37,614 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-13 22:02:37,619 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-13 22:02:37,620 : INFO : EPOCH - 5 : training on 1897565 raw words (1782639 effective words) took 3.2s, 552337 effective words/s
# 2018-09-13 22:02:37,621 : INFO : training on a 9487825 raw words (8911457 effective words) took 15.0s, 595586 effective words/s

# %%
model.wv.most_similar('여자는')
# Out:
# 2018-09-13 22:02:41,316 : INFO : precomputing L2-norms of word weight vectors
# [('우는', 0.9530857801437378),
#  ('여잔', 0.9510053992271423),
#  ('많은데', 0.9463465213775635),
#  ('건데', 0.9461692571640015),
#  ('남자는', 0.9460813403129578),
#  ('어디가', 0.9450017213821411),
#  ('여자가', 0.9436067938804626),
#  ('그렇지', 0.9427703619003296),
#  ('나잖아', 0.9417459964752197),
#  ('이제와', 0.9415667057037354)]

# %%
model2.wv.most_similar('여자는')
# Out:
# 2018-09-13 22:02:42,766 : INFO : precomputing L2-norms of word weight vectors
# [('여잔', 0.8937580585479736),
#  ('표정관리', 0.8479340672492981),
#  ('세븐틴은', 0.8393033742904663),
#  ('이것', 0.8325426578521729),
#  ('알다가도', 0.8262847661972046),
#  ('모르겠고', 0.8140408992767334),
#  ('너아니면', 0.8125070333480835),
#  ('못살아', 0.8120565414428711),
#  ('대걸레로', 0.8120372295379639),
#  ('재려', 0.8098004460334778)]

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile("해.")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(newlist)

# %%
Counter(newlist).most_common(20)

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile("해.")
newlist2 = list(filter(r.match, tokens_all2)) # Read Note
print(newlist2)

# %%
Counter(newlist2).most_common(20)

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile(r"[돼|되].")
newlist2 = list(filter(r.match, tokens_all2)) # Read Note
print(newlist2)

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile(r"[돼|되].")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(newlist)

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
# '요'로 끝나는 단어들을 봄으로써 존댓말 가사의 빈도수를 본다
import re

r = re.compile(r".[은|는|해|세|돼|줘|어|까|가|아|에|이|래|예|녜|마|게|구|지|네|와|나|라|봐|져|퍼|워]요$")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(len(newlist))
# Out:
# 3853

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
# '요'로 끝나는 단어들을 봄으로써 존댓말 가사의 빈도수를 본다
import re

r = re.compile(r".[은|까|는|해|세|돼|줘|어|가|아|에|이|래|예|녜|마|게|구|지|네|와|나|라|봐|져|퍼|워]요$")
newlist2 = list(filter(r.match, tokens_all2)) # Read Note
print(len(newlist2))
# Out:
# 4419

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
# '요'로 끝나는 단어들을 봄으로써 존댓말 가사의 빈도수를 본다
import re

r = re.compile(r".[해|세|돼|줘|어|까|래]$")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(len(newlist), newlist)
# Out:
# 17326 ['들어', '위해', '위해', '위해', '짙어', '짙어', '싫어', '없어', '싫어', '없어', '싫어', '없어', '싫어', '했어', '했어', '들어', '위해', '있어', '없어', '그래', '없어', '그래', '없어', '없어', '있어', '없어', '있어', '없어', '피해', '몰래', '피해', '있어', '위해', '위해', '알어', '없어', '없어', '알어', '없어', '위해', '알어', '없어', '싫어', '있어', '되어', '믿어', '믿어', '노래', '해줘', '위해', '싶어', '싶어', '싶어', '없어', '없어', '싫어', '싫어', '있어', '있어', '몰래', '싶어', '들어', '오래', '줄래', '그래', '아래', '그래', '있어', '있어', '아래', '그래', '아래', '그래', '싶어', '없어', '걸까', '그래', '되어', '넘어', '언어', '몰래', '없어', '있어', '싶어', '있어', '있어', '잘해', '바래', '있어', '싶어', '있어', '있어', '잘해', '바래', '있어', '반해', '없어', '반해', '없어', '못해', '말해', '됐어', '말해', '됐어', '말해', '됐어', '있어', '있어', '말해', '말해', '됐어', '말해', '됐어', '있어', '있어', '아래', '지어', '바래', '변해', '없어', '지어', '바래', '싶어', '지어', '바래', '없어', '있어', '깊어', '있어', '있어', '없어', '있어', '있어', '있어', '되어', '뭐해', '싫어', '없어', '없어', '없어', '없어', '봐줘', '봐줘', '봐줘', '봐줘', '못해', '말해', '됐어', '말해', '됐어', '말해', '됐어', '있어', '있어', '말해', '말해', '됐어', '말해', '됐어', '있어', '있어', '없어', '전해', '없어', '들어', '반해', '없어', '반해', '위해', '위해', '위해', '향해', '향해', '향해', '향해', '향해', '될까', '말해', '있어', '말해', '믿어', '말해', '있어', '말해', '있어', '말해', '못해', '못해', '못해', '못해', '했어', '못해', '못해', '없어', '있어', '싶어', '싶어', '있어', '
'싫어', '싶어', '싶어', '되어', '들어', '없어', '들어', '들어', '없어', '없어', '열어', '위해', '위해', '되어', '없어', '위해', '있어', '없어', '없어', '싫어', '없어', '없어', '싫어', '싫어', '못해', '없어', '싫어', '열어', '열어', '없어', '됐어', '싶어', '척해', '싫어', '척해', '싫어', '척해', '끊어', '없어', '싫어', '싶어', '걸어', '위해', '위해', '원해', '되어', '싶어', '없어', '없어', '없어', '없어', '못해', '싶어', '없어', '와줘', '없어', '물어', '내어', '싶어', '싶어', '알까', '있어', '오래', '없어', '위해', '싶어', '싶어', '싶어', '있어', '없어', '없어', '싶어', '싶어', '위해', '위해', '위해', '원해', '없어', '원해', '와줘', '위해', '해줘', '그래', '그래', '뭐해', '있어', '볼까', '싶어', '있어', '싶어', '했어', '안돼', '안돼', '없어', '없어', '위해', '말해', '원해', '바래', '했어', '될까', '오래', '오래', '위해', '열어', '되어', '있어', '있어', '없어', '있어', '없어', '없어', '싫어', '믿어', '없어', '없어', '했어 ...

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
# '요'로 끝나는 단어들을 봄으로써 존댓말 가사의 빈도수를 본다
import re

r = re.compile(r".[해|세|돼|줘|까|어|래]$")
newlist2 = list(filter(r.match, tokens_all2)) # Read Note
print(len(newlist2), newlist2)
# Out:
# 39715 ['없어', '있어', '있어', '없어', '죽어', '갔어', '있어', '갔어', '있어', '위해', '있어', '됐어', '없어', '벗어', '있어', '없어', '벗어', '있어', '싶어', '젖어', '말해', '위해', '없어', '없어', '위해', '있어', '있어', '위해', '있어', '웃어', '했어', '싶어', '싫어', '바래', '있어', '위해', '있어', '있어', '있어', '싶어', '됐어', '됐어', '됐어', '됐어', '됐어', '족해', '족해', '족해', '족해', '있어', '있어', '됐어', '됐어', '됐어', '됐어', '됐어', '족해', '족해', '족해', '족해', '위해', '있어', '있어', '됐어', '됐어', '됐어', '됐어', '됐어', '됐어', '걸까', '있어', '됐어', '있어', '그래', '걸까', '걸까', '다해', '있어', '됐어', '없어', '늦어', '다해', '있어', '됐어', '걸까', '있어', '됐어', '있어', '그래', '걸까', '걸까', '갔어', '있어', '갔어', '있어', '위해', '했어', '있어', '없어', '있어', '있어', '없어', '죽어', '됐어', '없어', '벗어', '있어', '없어', '벗어', '있어', '있어', '있어', '싶어', '싶어', '다해', '못해', '있어', '있어', '있어', '껐어', '있어', '쳤어', '있어', '있어', '있어', '싶어', '싶어', '싶어', '싶어', '싶어', '싶어', '없어', '됐어', '됐어', '됐어', '됐어', '족해', '족해', '족해', '늘어', '집어', '있어', '있어', '있어', '있어', '됐어', '됐어', '됐어', '됐어', '있어', '있어', '있어', '싶어', '안돼', '없어', '싫어', '없어', '싫어', '없어', '싫어', '늦어', '있어', '싶어', '싶어', '싶어', '싶어', '싶어', '없어', '껐어', '있어', '쳤어', '있어', '있어', '있어', '있어', '있어', '있어', '있어', '있어', '싶어', '됐어', '됐어', '됐어', '됐어', '됐어', '족해', '족해', '족해', '족해', '있어', '있어', '됐어', '됐어', '됐어', '됐어', '됐어', '족해', '족해', '족해', '족해', '위해', '있어', '
', '싶어', '위해', '싶어', '싶어', '싶어', '쓸어', '있어', '들어', '몰래', '싶어', '쓸어', '있어', '없어', '위해', '위해', '위해', '위해', '왔어', '할까', '했어', '피해', '없어', '없어', '했어', '그래', '있어', '봤어', '그래', '있어', '있어', '없어', '위해', '있어', '위해', '있어', '있어', '싶어', '쓸어', '있어', '들어', '몰래', '싶어', '쓸어', '있어', '할까', '웃어', '피해', '없어', '없어', '없어', '있어', '할까', '위해', '할까', '없어', '할까', '할까', '위해', '있어', '두해', '더해', '두해', '더해', '이해', '싶어', '싶어', '싶어', '싶어', '위해', '싶어', '싶어', '싶어', '싶어', '싶어', '위해', '해줘', '오래', '오래', '원해', '오래', '오래', '위해', '그래', '위해', '위해', '위해', '했어', '그래', '있어', '봤어', '했어', '그래', '있어', '봤어', '인해', '들어', '인해', '들어', '그래', '위해', '인해', '들어', '인해', '들어', '오래', '오래', '되어', '되어', '였어 ...

# %%
없|있|열|잊|했|싶|갔|어

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile(".{1,4}요$")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(len(newlist))
# Out:
# 10698

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile(".{1,4}요$")
newlist2 = list(filter(r.match, tokens_all2)) # Read Note
print(len(newlist2))
# Out:
# 13303

# %%
# '필요'라는 단어는 어미가 포함되지 않은 단어이므로 제외한다.
import re

r = re.compile("^(?!.*필).*$")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(len(newlist))
# Out:
# 927015

# %%
# '필요'라는 단어는 어미가 포함되지 않은 단어이므로 제외한다.
import re

r = re.compile("^(?!.*필).*$")
newlist2 = list(filter(r.match, newlist2)) # Read Note
print(len(newlist2))
# Out:
# 12835

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile(".주세요$")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(newlist)

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile(".주세요$")
newlist2 = list(filter(r.match, tokens_all2)) # Read Note
print(newlist2)

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile(".줄게$")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(newlist)

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile(".지마$")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(len(newlist), newlist)
# Out:
# 1077 ['하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '놓지마', '놓지마', '두지마', '놓지마', '하지마', '하지마', '하지마', '오지마', '찾지마', '오지마', '찾지마', '오지마', '찾지마', '오지마', '찾지마', '오지마', '찾지마', '오지마', '찾지마', '하지마', '하지마', '따지마', '하지마', '하지마', '잊지마', '하지마', '잊지마', '잊지마', '오지마', '하지마', '내지마', '두지마', '오지마', '하지마', '내지마', '두지마', '오지마', '하지마', '내지마', '두지마', '쓰지마', '가지마', '잊지마', '보지마', '서지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '울지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '가지마', '가지마', '하지마', '하지마', '찾지마', '놓지마', '보지마', '하지마', '하지마', '하지마', '하지마', '오지마', '오지마', '하지마', '하지마', '믿지마', '하지마', '하지마', '하지마', '가지마', '하지마', '울지마', '잊지마', '잊지마', '하지마', '하지마', '하지마', '하지마', '하지마', '잊지마', '잊지마', '하지마', '하지마', '하지마', '하지마', '하지마', '보지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '하지마', '가지마', '가지마', '하지마', '하지마', '찾지마', '하지마', '하지마', '가지마', '가지마', '가지마', '가지마', '믿지마', '오지마', '하지마', '하지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '가지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '찾지마', '하지마', '하지마', '보지마', '하지마', '하지마', '하지마', '막지마', '막지마', '막지마', '막지마', '입지마', '하지마', '하지마', '갖지마', '하지마', '갖지마', '하지마', '하지마', '하지마', '가지마', '하지마', '놓지마', '하지마', '하지마', '하지마', '보지마', '잊지마', '잊지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마', '하지마',
'오빠', '오빠', '오빠', '오빠', '오빠', '오빠야', '오빠', '오빠', '오빠도', '오빠']

# %%
# 남자아이돌 가사 속 오빠
import re

r = re.compile("오빠")
newlist2 = list(filter(r.match, tokens_all2)) # Read Note
print(len(newlist2), newlist2)
# Out:
# 241 ['오빠가', '오빠', '오빠들', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠만', '오빠가', '오빠만', '오빠만', '오빠가', '오빠만', '오빠가', '오빠만', '오빠가', '오빠만', '오빠', '오빠', '오빠로', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠들한테', '오빠야', '오빠는', '오빠는', '오빠는', '오빠는', '오빠는', '오빠는', '오빠', '오빠', '오빠처럼', '오빠처럼', '오빠', '오빠', '오빠', '오빠가', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠들', '오빠', '오빠만', '오빠', '오빠야', '오빠라며', '오빠', '오빠', '오빠든', '오빠든', '오빠든', '오빠든', '오빠든', '오빠', '오빠동생', '오빠동생', '오빠오빠', '오빠동생', '오빠동생', '오빠', '오빠', '오빠들도', '오빠나', '오빠가', '오빠', '오빠가', '오빠', '오빠', '오빠', '오빠', '오빠', '오빠야네', '오빠', '오빠', '오빠', '오빠', '오빠야네', '오빠들에', '오빠', '오빠', '오빠라는', '오빠라고', '오빠라고', '오빠에', '오빠처럼', '오빠', '오빠', '오빠']

# %%
# 남자아이돌 가사 속 누나
import re

r = re.compile("누나")
newlist2 = list(filter(r.match, tokens_all2)) # Read Note
print(len(newlist2), newlist2)
# Out:
# 85 ['누나', '누나', '누나', '누나', '누나', '누나보다', '누나만', '누나라는', '누나', '누나', '누나에게', '누나일꺼라고만', '누나일꺼라고만', '누나', '누나와', '누나들한테', '누나들', '누나', '누나', '누나', '누나', '누나', '누나의', '누나의', '누나가', '누나와', '누나지만', '누나의', '누나와', '누나지만', '누나지만', '누나들보단', '누나들의', '누나야', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나를', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나', '누나는', '누나', '누나', '누나', '누나', '누나야가', '누나야가', '누나의', '누나건', '누나건', '누나와', '누나라고', '누나', '누나라고', '누나라고', '누나의', '누나의', '누나의', '누나라', '누나도', '누나의', '누나의']

# %%
# 여자아이돌 가사 속 누나
import re

r = re.compile("누나")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(len(newlist), newlist)
# Out:
# 16 ['누나래', '누나', '누나처럼', '누나처럼', '누나처럼', '누나', '누나', '누나', '누나가', '누나', '누나한테', '누나가', '누나', '누나여', '누나여', '누나여']

# %%
# 여자아이돌 가사 속 너
import re

r = re.compile("너")
newlist = list(filter(r.match, tokens_all)) # Read Note
print(len(newlist), newlist)
# Out:
# 23031 ['너무', '너만을', '너의', '너는', '너만을', '너에게', '너의', '너는', '너만을', '너만을', '너무도', '너무도', '너를', '너무', '너의', '너를', '너무', '너의', '너무', '너의', '너를', '너를', '너의', '너에게', '너를', '너를', '너의', '너에', '너의', '너의', '너의', '너의', '너와', '너를', '너무', '너의', '너의', '너의', '너의', '너의', '너에', '너의', '너의', '너의', '너는', '너를', '너에게', '너를', '너란걸', '너의', '너에게', '너를', '너의', '너때문에', '너너너', '너를지켜보고', '너무', '너였잖아', '너였잖아', '너만을', '너의', '너에게', '너만큼', '너무싫어', '너에게', '너만큼', '너무쉽게', '너의곁에', '너만의', '너의', '너무쉽게', '너의곁에', '너만의', '너무쉽게', '너의곁에', '너만의', '너자꾸', '너무많은', '너의', '너자꾸', '너자꾸', '너만
', '너를', '너는', '너무나', '너를', '너를', '너무', '너를', '너무', '너를', '너를', '너를', '너는', '너의', '너는', '너를', '너는', '너는', '너를', '너에게', '너에게', '너도', '너를', '너를', '너의', '너무', '너에게', '너와', '너에게', '너와', '너의', '너의', '너무', '너와', '너를', '너를', '너를', '너는', '너와', '너를', '너를', '너는', '너와', '너를', '너는', '너무', '너무', '너를', '너에게', '너', '너', '너와', '너의', '너를', '너를', '너를', '너', '너', '너무', '너를', '너', '너와', '너를', '너를', '너를', '너무', '너와', '너도', '너에게', '너', '너도', '너의', '너와', '너도', '너에게', '너', '너에게', '너와', '너에게', '너', '너에게', '너', '너와', '너를', '너의', '너로', '너와', '너를', '너의', '너로', '너의', '너의', '너로', '너의', '너로', '너는', '너무', '너는', '너무', '너의', '너였다니', '너야', '너를', '너였다니', '너는', '너는', '너무도', '너를', '너무도', '너를', '너의', '너를', '너를', '너의', '너도', '너의', '너의', '너의', '너와', '너와', '너를', '너를', '너무', '너를', '너무', '너를', '너를', '너를', '너무', '너와', '너의', '너에게', '너를', '너처럼', ...

# %%
Counter(newlist).most_common(20)
# Out:
# [('말아요', 273),
#  ('있어요', 164),
#  ('없어요', 157),
#  ('몰라요', 148),
#  ('있나요', 133),
#  ('해봐요', 130),
#  ('좋아요', 122),
#  ('않아요', 113),
#  ('그래요', 105),
#  ('싶어요', 101),
#  ('아나요', 93),
#  ('주세요', 89),
#  ('없나요', 84),
#  ('믿어요', 82),
#  ('말해요', 73),
#  ('알아요', 68),
#  ('같아요', 65),
#  ('뭐예요', 60),
#  ('거예요', 58),
#  ('건가요', 53)]

# %%
Counter(newlist2).most_common(20)
# Out:
# [('말아요', 407),
#  ('있어요', 260),
#  ('있나요', 229),
#  ('없어요', 186),
#  ('않아요', 123),
#  ('알아요', 121),
#  ('싶어요', 120),
#  ('믿어요', 116),
#  ('같아요', 114),
#  ('그래요', 107),
#  ('잡아요', 85),
#  ('없나요', 85),
#  ('줄게요', 80),
#  ('몰라요', 71),
#  ('안돼요', 69),
#  ('떠나요', 67),
#  ('거예요', 65),
#  ('없네요', 65),
#  ('말해요', 62),
#  ('웃어요', 59)]

# %%
Counter(newlist).most_common(30)
# Out:
# [('하지마', 449),
#  ('가지마', 194),
#  ('떠나지마', 77),
#  ('떠나가지마', 56),
#  ('찾지마', 52),
#  ('바라보지마', 48),
#  ('웃지마', 41),
#  ('보지마', 38),
#  ('멈추지마', 35),
#  ('망설이지마', 32),
#  ('행복하지마', 32),
#  ('놓지마', 31),
#  ('걱정하지마', 29),
#  ('말하지마', 28),
#  ('울리지마', 28),
#  ('잊지마', 26),
#  ('부르지마', 23),
#  ('서두르지마', 19),
#  ('붙지마', 19),
#  ('주저하지마', 17),
#  ('이러지마', 17),
#  ('기다리지마', 17),
#  ('두지마', 16),
#  ('가져가지마', 16),
#  ('오지마', 15),
#  ('생각하지마', 15),
#  ('놓치지마', 15),
#  ('착각하지마', 15),
#  ('묻지마', 15),
#  ('잡지마', 15)]

# %%
Counter(newlist2).most_common(30)
# Out:
# [('하지마', 695),
#  ('가지마', 232),
#  ('떠나지마', 137),
#  ('울지마', 128),
#  ('잊지마', 113),
#  ('멈추지마', 89),
#  ('떠나가지마', 85),
#  ('걱정하지마', 73),
#  ('보지마', 73),
#  ('이러지마', 65),
#  ('말하지마', 60),
#  ('막지마', 39),
#  ('두지마', 37),
#  ('망설이지마', 37),
#  ('버리지마', 35),
#  ('놓지마', 35),
#  ('까불지마', 35),
#  ('찾지마', 33),
#  ('사랑하지마', 32),
#  ('생각하지마', 28),
#  ('포기하지마', 28),
#  ('살지마', 24),
#  ('말리지마', 24),
#  ('피하지마', 23),
#  ('쓰지마', 20),
#  ('믿지마', 20),
#  ('슬퍼하지마', 18),
#  ('착각하지마', 18),
#  ('놓치지마', 18),
#  ('의심하지마', 18)]

# %%
Counter(newlist).most_common(30)
# Out:
# [('하지마', 449),
#  ('가지마', 194),
#  ('찾지마', 52),
#  ('웃지마', 41),
#  ('보지마', 38),
#  ('놓지마', 31),
#  ('잊지마', 26),
#  ('붙지마', 19),
#  ('두지마', 16),
#  ('오지마', 15),
#  ('묻지마', 15),
#  ('잡지마', 15),
#  ('팔지마', 15),
#  ('속지마', 13),
#  ('굴지마', 13),
#  ('울지마', 9),
#  ('먹지마', 9),
#  ('치지마', 9),
#  ('쓰지마', 8),
#  ('듣지마', 8),
#  ('빼지마', 8),
#  ('막지마', 6),
#  ('놀지마', 6),
#  ('대지마', 5),
#  ('주지마', 5),
#  ('걸지마', 5),
#  ('내지마', 3),
#  ('믿지마', 3),
#  ('갖지마', 3),
#  ('있지마', 3)]

# %%
Counter(newlist2).most_common(30)
# Out:
# [('하지마', 695),
#  ('가지마', 232),
#  ('울지마', 128),
#  ('잊지마', 113),
#  ('보지마', 73),
#  ('막지마', 39),
#  ('두지마', 37),
#  ('놓지마', 35),
#  ('찾지마', 33),
#  ('살지마', 24),
#  ('쓰지마', 20),
#  ('믿지마', 20),
#  ('입지마', 18),
#  ('묻지마', 16),
#  ('쫄지마', 16),
#  ('갖지마', 14),
#  ('있지마', 14),
#  ('잡지마', 11),
#  ('되지마', 11),
#  ('웃지마', 11),
#  ('짓지마', 10),
#  ('빼지마', 10),
#  ('주지마', 9),
#  ('숨지마', 9),
#  ('떨지마', 9),
#  ('오지마', 9),
#  ('튀지마', 8),
#  ('내지마', 7),
#  ('받지마', 5),
#  ('잃지마', 5)]

# %%
male['lyrics'][male['lyrics'].str.contains('해줄게')]

# %%
doit = doit['lyrics'][female['lyrics'].str.contains('해줄게')]

# %%
search_word2 = '해줄게'

# %%
indices = [i for i, x in enumerate() if x == search_word2]

# %%
next_word = tokens_all[tokens_all.index(search_word2):tokens_all.index(search_word) + 5]
next_word

# %%
# tf-idf로 여자 아이돌의 가사에만 많이 나오는 단어, 남자 아이돌의 가사에만 많이 나오는 단어를 보고 싶다.

# %%
# 정규표현식을 이용하여 어떤 어미가 쓰였는지 알아본다.
import re

r = re.compile(".줄게$")
newlist2 = list(filter(r.match, tokens_all2)) # Read Note
print(newlist2)
